# %% [markdown]
# # Association Rule - Apriori and ECLAT
#
# Training association rule models (Apriori and ECLAT) to find the most related items bought by customers of a french supermarket during a week. All 7501 lines of the dataset represent items bought by an unique customer, during this week.
#
# This algorithm associate products preferences by most of the customers and can be used to generate products recommendation and help on displaying products strategy.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data Loading
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# Adding all customers into a list of lists
transactions = []
for i in range(0, len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
dataset.head(20)
# Out:
#                    0             1              2                 3   \
# 0              shrimp       almonds        avocado    vegetables mix
# 1             burgers     meatballs           eggs               NaN
# 2             chutney           NaN            NaN               NaN
# 3              turkey       avocado            NaN               NaN
# 4       mineral water          milk     energy bar  whole wheat rice
# 5      low fat yogurt           NaN            NaN               NaN
# 6   whole wheat pasta  french fries            NaN               NaN
# 7                soup   light cream        shallot               NaN
# 8   frozen vegetables     spaghetti      green tea               NaN
# 9        french fries           NaN            NaN               NaN
# 10               eggs      pet food            NaN               NaN
# 11            cookies           NaN            NaN               NaN
# 12             turkey       burgers  mineral water              eggs
# 13          spaghetti     champagne        cookies               NaN
# 14      mineral water        salmon            NaN               NaN
# 15      mineral water           NaN            NaN               NaN
# 16             shrimp     chocolate        chicken             honey
# 17             turkey          eggs            NaN               NaN
# 18             turkey    fresh tuna       tomatoes         spaghetti
# 19          meatballs          milk          honey      french fries
#
#                4                 5               6               7   \
# 0    green grapes  whole weat flour            yams  cottage cheese
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4       green tea               NaN             NaN             NaN
# 5             NaN               NaN             NaN             NaN
# 6             NaN               NaN             NaN             NaN
# 7             NaN               NaN             NaN             NaN
# 8             NaN               NaN             NaN             NaN
# 9             NaN               NaN             NaN             NaN
# 10            NaN               NaN             NaN             NaN
# 11            NaN               NaN             NaN             NaN
# 12    cooking oil               NaN             NaN             NaN
# 13            NaN               NaN             NaN             NaN
# 14            NaN               NaN             NaN             NaN
# 15            NaN               NaN             NaN             NaN
# 16            oil       cooking oil  low fat yogurt             NaN
# 17            NaN               NaN             NaN             NaN
# 18  mineral water         black tea          salmon            eggs
# 19    protein bar               NaN             NaN             NaN
#
#               8                     9               10         11     12  \
# 0   energy drink          tomato juice  low fat yogurt  green tea  honey
# 1            NaN                   NaN             NaN        NaN    NaN
# 2            NaN                   NaN             NaN        NaN    NaN
# 3            NaN                   NaN             NaN        NaN    NaN
# 4            NaN                   NaN             NaN        NaN    NaN
# 5            NaN                   NaN             NaN        NaN    NaN
# 6            NaN                   NaN             NaN        NaN    NaN
# 7            NaN                   NaN             NaN        NaN    NaN
# 8            NaN                   NaN             NaN        NaN    NaN
# 9            NaN                   NaN             NaN        NaN    NaN
# 10           NaN                   NaN             NaN        NaN    NaN
# 11           NaN                   NaN             NaN        NaN    NaN
# 12           NaN                   NaN             NaN        NaN    NaN
# 13           NaN                   NaN             NaN        NaN    NaN
# 14           NaN                   NaN             NaN        NaN    NaN
# 15           NaN                   NaN             NaN        NaN    NaN
# 16           NaN                   NaN             NaN        NaN    NaN
# 17           NaN                   NaN             NaN        NaN    NaN
# 18       chicken  extra dark chocolate             NaN        NaN    NaN
# 19           NaN                   NaN             NaN        NaN    NaN
#
#        13             14      15                 16               17       18  \
# 0   salad  mineral water  salmon  antioxydant juice  frozen smoothie  spinach
# 1     NaN            NaN     NaN                NaN              NaN      NaN
# 2     NaN            NaN     NaN                NaN              NaN      NaN
# 3     NaN            NaN     NaN                NaN              NaN      NaN
# 4     NaN            NaN     NaN                NaN              NaN      NaN
# 5     NaN            NaN     NaN                NaN              NaN      NaN
# 6     NaN            NaN     NaN                NaN              NaN      NaN
# 7     NaN            NaN     NaN                NaN              NaN      NaN
# 8     NaN            NaN     NaN                NaN              NaN      NaN
# 9     NaN            NaN     NaN                NaN              NaN      NaN
# 10    NaN            NaN     NaN                NaN              NaN      NaN
# 11    NaN            NaN     NaN                NaN              NaN      NaN
# 12    NaN            NaN     NaN                NaN              NaN      NaN
# 13    NaN            NaN     NaN                NaN              NaN      NaN
# 14    NaN            NaN     NaN                NaN              NaN      NaN
# 15    NaN            NaN     NaN                NaN              NaN      NaN
# 16    NaN            NaN     NaN                NaN              NaN      NaN
# 17    NaN            NaN     NaN                NaN              NaN      NaN
# 18    NaN            NaN     NaN                NaN              NaN      NaN
# 19    NaN            NaN     NaN                NaN              NaN      NaN
#
#            19
# 0   olive oil
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %% [markdown]
# ### Apriori implementation using apyori library
# source: https://github.com/ymoch/apyori
#
# The output of this part is to see which are the products that used to be more bought in combination compared to other combinations using apriori algorithm.
#
# We will put some transformations to fit on dataframes and to make the visualization easier.

# %%
# Inspecting elements
transactions[:3]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
# Training Apriori on the dataset
# The hyperparameters choosen on this training are:
# min_support = items bought more than 3 times a day * 7 days (week) / 7500 customers = 0.0028
# min_confidence: at least 20%, min_lift = minimum of 3 (less than that is too low)
# min_length: we want at least 2 items to be associated. No point in having a single item in the result

from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
# Visualising the results
results = list(rules)

# %%
lift = []
association = []
for i in range (0, len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %% [markdown]
# ### Visualizing results in a dataframe

# %%
rank = pd.DataFrame([association, lift]).transpose()
rank.columns = ['Association', 'Lift']

# %%
# Show top 10 higher lift scores
rank.sort_values('Lift', ascending=False).head(10)
# Out:
#                                            Association      Lift
# 150  [frozen vegetables, milk, nan, mineral water, ...  7.987176
# 97      [frozen vegetables, mineral water, soup, milk]  7.987176
# 149  [frozen vegetables, milk, nan, mineral water, ...  6.128268
# 96   [frozen vegetables, mineral water, olive oil, ...  6.128268
# 132  [mineral water, whole wheat pasta, olive oil, ...  6.128268
# 59       [mineral water, whole wheat pasta, olive oil]  6.115863
# 50              [spaghetti, tomato sauce, ground beef]  5.535971
# 122        [spaghetti, nan, tomato sauce, ground beef]  5.535971
# 28                         [honey, fromage blanc, nan]  5.178818
# 3                               [honey, fromage blanc]  5.164271

# %% [markdown]
# By the study, "olive oil, whole wheat pasta, mineral water" are the most commom combined items from this week for the supermarket in question.

# %% [markdown]
# ## ECLAT Implementation
#
# This is an implementation of the ECLAT code by hand. It calculate the pairs that have been bought more frequently comparing to other pairs. At the end, we expect to see what is the most common combination of products during the week.
#
# An extension of the code can calculate the three most common combination, 4, and so on.

# %% [markdown]
# #### Getting the list of products bought this week by all customers

# %%
# Putting all transactions in a single list
itens = []
for i in range(0, len(transactions)):
    itens.extend(transactions[i])

# Finding unique items from transactions and removing nan
uniqueItems = list(set(itens))
uniqueItems.remove('nan')

# %%
uniqueItems
# Out:
# ['red wine',
#  'antioxydant juice',
#  'grated cheese',
#  'herb & pepper',
#  'mineral water',
#  'light cream',
#  'shallot',
#  'bramble',
#  'eggs',
#  'whole weat flour',
#  'spaghetti',
#  'carrots',
#  'water spray',
#  'burger sauce',
#  'cooking oil',
#  'almonds',
#  'hand protein bar',
#  'black tea',
#  'strawberries',
#  'mint green tea',
#  'napkins',
#  'gums',
#  'vegetables mix',
#  'asparagus',
#  'pasta',
#  'chocolate bread',
#  'tea',
#  'whole wheat pasta',
#  'extra dark chocolate',
#  'zucchini',
#  'butter',
#  'cauliflower',
#  'protein bar',
#  'turkey',
#  'low fat yogurt',
#  'barbecue sauce',
#  'champagne',
#  'mushroom cream sauce',
#  'dessert wine',
#  'energy bar',
#  'parmesan cheese',
#  'magazines',
#  'pickles',
#  'mashed potato',
#  'green tea',
#  'light mayo',
#  'avocado',
#  'sandwich',
#  'bug spray',
#  'frozen smoothie',
#  'flax seed',
#  'burgers',
#  'fresh bread',
#  'yams',
#  'blueberries',
#  'shampoo',
#  'whole wheat rice',
#  'body spray',
#  'energy drink',
#  'hot dogs',
#  'oatmeal',
#  'tomato juice',
#  'pet food',
#  'clothes accessories',
#  'mayonnaise',
#  'meatballs',
#  'shrimp',
#  'babies food',
#  'nonfat milk',
#  'bacon',
#  'cereals',
#  'honey',
#  'soda',
#  'yogurt cake',
#  'salmon',
#  'brownies',
#  'green grapes',
#  'pepper',
#  'white wine',
#  'soup',
#  'mint',
#  'ham',
#  'cream',
#  'tomatoes',
#  'cake',
#  'toothpaste',
#  'frozen vegetables',
#  'sparkling water',
#  'green beans',
#  'cottage cheese',
#  'strong cheese',
#  'french wine',
#  'french fries',
#  'cookies',
#  'fromage blanc',
#  'ketchup',
#  ' asparagus',
#  'eggplant',
#  'spinach',
#  'chutney',
#  'salt',
#  'rice',
#  'escalope',
#  'corn',
#  'cider',
#  'candy bars',
#  'melons',
#  'milk',
#  'pancakes',
#  'gluten free bar',
#  'tomato sauce',
#  'muffins',
#  'olive oil',
#  'chicken',
#  'salad',
#  'oil',
#  'chocolate',
#  'fresh tuna',
#  'ground beef',
#  'chili']

# %% [markdown]
# #### Creating combinations with the items - pairs

# %%
pair = []
for j in range(0, len(uniqueItems)):
    k = 1;
    while k <= len(uniqueItems):
        try:
            pair.append([uniqueItems[j], uniqueItems[j+k]])
        except IndexError:
            pass
        k = k + 1;

# %%
pair
# Out:
# [['red wine', 'antioxydant juice'],
#  ['red wine', 'grated cheese'],
#  ['red wine', 'herb & pepper'],
#  ['red wine', 'mineral water'],
#  ['red wine', 'light cream'],
#  ['red wine', 'shallot'],
#  ['red wine', 'bramble'],
#  ['red wine', 'eggs'],
#  ['red wine', 'whole weat flour'],
#  ['red wine', 'spaghetti'],
#  ['red wine', 'carrots'],
#  ['red wine', 'water spray'],
#  ['red wine', 'burger sauce'],
#  ['red wine', 'cooking oil'],
#  ['red wine', 'almonds'],
#  ['red wine', 'hand protein bar'],
#  ['red wine', 'black tea'],
#  ['red wine', 'strawberries'],
#  ['red wine', 'mint green tea'],
#  ['red wine', 'napkins'],
#  ['red wine', 'gums'],
#  ['red wine', 'vegetables mix'],
#  ['red wine', 'asparagus'],
#  ['red wine', 'pasta'],
#  ['red wine', 'chocolate bread'],
#  ['red wine', 'tea'],
#  ['red wine', 'whole wheat pasta'],
#  ['red wine', 'extra dark chocolate'],
#  ['red wine', 'zucchini'],
#  ['red wine', 'butter'],
#  ['red wine', 'cauliflower'],
#  ['red wine', 'protein bar'],
#  ['red wine', 'turkey'],
#  ['red wine', 'low fat yogurt'],
#  ['red wine', 'barbecue sauce'],
#  ['red wine', 'champagne'],
#  ['red wine', 'mushroom cream sauce'],
#  ['red wine', 'dessert wine'],
#  ['red wine', 'energy bar'],
#  ['red wine', 'parmesan cheese'],
#  ['red wine', 'magazines'],
#  ['red wine', 'pickles'],
#  ['red wine', 'mashed potato'],
#  ['red wine', 'green tea'],
#  ['red wine', 'light mayo'],
#  ['red wine', 'avocado'],
#  ['red wine', 'sandwich'],
#  ['red wine', 'bug spray'],
#  ['red wine', 'frozen smoothie'],
#  ['red wine', 'flax seed'],
#  ['red wine', 'burgers'],
#  ['red wine', 'fresh bread'],
#  ['red wine', 'yams'],
#  ['red wine', 'blueberries'],
#  ['red wine', 'shampoo'],
#  ['red wine', 'whole wheat rice'],
#  ['red wine', 'body spray'],
#  ['red wine', 'energy drink'],
#  ['red wine', 'hot dogs'],
#  ['red wine', 'oatmeal'],
#  ['red wine', 'tomato juice'],
#  ['red wine', 'pet food'],
#  ['red wine', 'clothes accessories'],
#  ['red wine', 'mayonnaise'],
#  ['red wine', 'meatballs'],
#  ['red wine', 'shrimp'],
#  ['red wine', 'babies food'],
#  ['red wine', 'nonfat milk'],
#  ['red wine', 'bacon'],
#  ['red wine', 'cereals'],
#  ['red wine', 'honey'],
#  ['red wine', 'soda'],
#  ['red wine', 'yogurt cake'],
#  ['red wine', 'salmon'],
#  ['red wine', 'brownies'],
#  ['red wine', 'green grapes'],
#  ['red wine', 'pepper'],
#  ['red wine', 'white wine'],
#  ['red wine', 'soup'],
#  ['red wine', 'mint'],
#  ['red wine', 'ham'],
#  ['red wine', 'cream'],
#  ['red wine', 'tomatoes'],
#  ['red wine', 'cake'],
#  ['red wine', 'toothpaste'],
#  ['red wine', 'frozen vegetables'],
#  ['red wine', 'sparkling water'],
#  ['red wine', 'green beans'],
#  ['red wine', 'cottage cheese'],
#  ['red wine', 'strong cheese'],
#  ['red wine', 'french wine'],
#  ['red wine', 'french fries'],
#  ['red wine', 'cookies'],
#  ['red wine', 'fromage blanc'],
#  ['red wine', 'ketchup'],
#  ['red wine', ' asparagus'],
#  ['red wine', 'eggplant'],
#  ['red wine', 'spinach'],
#  ['red wine', 'chutney'],
#  ['red wine', 'salt'],
#  ['red wine', 'rice'],
#  ['red wine', 'escalope'],
#  ['red wine', 'corn'],
#  ['red wine', 'cider'],
#  ['red wine', 'candy bars'],
#  ['red wine', 'melons'],
#  ['red wine', 'milk'],
#  ['red wine', 'pancakes'],
#  ['red wine', 'gluten free bar'],
#  ['red wine', 'tomato sauce'],
#  ['red wine', 'muffins'],
#  ['red wine', 'olive oil'],
#  ['red wine', 'chicken'],
#  ['red wine', 'salad'],
#  ['red wine', 'oil'],
#  ['red wine', 'chocolate'],
#  ['red wine', 'fresh tuna'],
#  ['red wine', 'ground beef'],
#  ['red wine', 'chili'],
#  ['antioxydant juice', 'grated cheese'],
#  ['antioxydant juice', 'herb & pepper'],
#  ['antioxydant juice', 'mineral water'],
#  ['antioxydant juice', 'light cream'],
#  ['antioxydant juice', 'shallot'],
#  ['antioxydant juice', 'bramble'],
#  ['antioxydant juice', 'eggs'],
#  ['antioxydant juice', 'whole weat flour'],
#  ['antioxydant juice', 'spaghetti'],
#  ['antioxydant juice', 'carrots'],
#  ['antioxydant juice', 'water spray'],
#  ['antioxydant juice', 'burger sauce'],
#  ['antioxydant juice', 'cooking oil'],
#  ['antioxydant juice', 'almonds'],
#  ['antioxydant juice', 'hand protein bar'],
#  ['antioxydant juice', 'black tea'],
#  ['antioxydant juice', 'strawberries'],
#  ['antioxydant juice', 'mint green tea'],
#  ['antioxydant juice', 'napkins'],
#  ['antioxydant juice', 'gums'],
#  ['antioxydant juice', 'vegetables mix'],
#  ['antioxydant juice', 'asparagus'],
#  ['antioxydant juice', 'pasta'],
#  ['antioxydant juice', 'chocolate bread'],
#  ['antioxydant juice', 'tea'],
#  ['antioxydant juice', 'whole wheat pasta'],
#  ['antioxydant juice', 'extra dark chocolate'],
#  ['antioxydant juice', 'zucchini'],
#  ['antioxydant juice', 'butter'],
#  ['antioxydant juice', 'cauliflower'],
#  ['antioxydant juice', 'protein bar'],
#  ['antioxydant juice', 'turkey'],
#  ['antioxydant juice', 'low fat yogurt'],
#  ['antioxydant juice', 'barbecue sauce'],
#  ['antioxydant juice', 'champagne'],
#  ['antioxydant juice', 'mushroom cream sauce'],
#  ['antioxydant juice', 'dessert wine'],
#  ['antioxydant juice', 'energy bar'],
#  ['antioxydant juice', 'parmesan cheese'],
#  ['antioxydant juice', 'magazines'],
#  ['antioxydant juice', 'pickles'],
#  ['antioxydant juice', 'mashed potato'],
#  ['antioxydant juice', 'green tea'],
#  ['antioxydant juice', 'light mayo'],
#  ['antioxydant juice', 'avocado'],
#  ['antioxydant juice', 'sandwich'],
#  ['antioxydant juice', 'bug spray'],
#  ['antioxydant juice', 'frozen smoothie'],
#  ['antioxydant juice', 'flax seed'],
#  ['antioxydant juice', 'burgers'],
#  ['antioxydant juice', 'fresh bread'],
#  ['antioxydant juice', 'yams'],
#  ['antioxydant juice', 'blueberries'],
#  ['antioxydant juice', 'shampoo'],
#  ['antioxydant juice', 'whole wheat rice'],
#  ['antioxydant juice', 'body spray'],
#  ['antioxydant juice', 'energy drink'],
#  ['antioxydant juice', 'hot dogs'],
#  ['antioxydant juice', 'oatmeal'],
#  ['antioxydant juice', 'tomato juice'],
#  ['antioxydant juice', 'pet food'],
#  ['antioxydant juice', 'clothes accessories'],
#  ['antioxydant juice', 'mayonnaise'],
#  ['antioxydant juice', 'meatballs'],
#  ['antioxydant juice', 'shrimp'],
#  ['antioxydant juice', 'babies food'],
#  ['antioxydant juice', 'nonfat milk'],
#  ['antioxydant juice', 'bacon'],
#  ['antioxydant juice', 'cereals'],
#  ['antioxydant juice', 'honey'],
#  ['antioxydant juice', 'soda'],
#  ['antioxydant juice', 'yogurt cake'],
#  ['antioxydant juice', 'salmon'],
#  ['antioxydant juice', 'brownies'],
#  ['antioxydant juice', 'green grapes'],
#  ['antioxydant juice', 'pepper'],
#  ['antioxydant juice', 'white wine'],
#  ['antioxydant juice', 'soup'],
#  ['antioxydant juice', 'mint'],
#  ['antioxydant juice', 'ham'],
#  ['antioxydant juice', 'cream'],
#  ['antioxydant juice', 'tomatoes'],
#  ['antioxydant juice', 'cake'],
#  ['antioxydant juice', 'toothpaste'],
#  ['antioxydant juice', 'frozen vegetables'],
#  ['antioxydant juice', 'sparkling water'],
#  ['antioxydant juice', 'green beans'],
#  ['antioxydant juice', 'cottage cheese'],
#  ['antioxydant juice', 'strong cheese'],
#  ['antioxydant juice', 'french wine'],
#  ['antioxydant juice', 'french fries'],
#  ['antioxydant juice', 'cookies'],
#  ['antioxydant juice', 'fromage blanc'],
#  ['antioxydant juice', 'ketchup'],
#  ['antioxydant juice', ' asparagus'],
#  ['antioxydant juice', 'eggplant'],
#  ['antioxydant juice', 'spinach'],
#  ['antioxydant juice', 'chutney'],
#  ['antioxydant juice', 'salt'],
#  ['antioxydant juice', 'rice'],
#  ['antioxydant juice', 'escalope'],
#  ['antioxydant juice', 'corn'],
#  ['antioxydant juice', 'cider'],
#  ['antioxydant juice', 'candy bars'],
#  ['antioxydant juice', 'melons'],
#  ['antioxydant juice', 'milk'],
#  ['antioxydant juice', 'pancakes'],
#  ['antioxydant juice', 'gluten free bar'],
#  ['antioxydant juice', 'tomato sauce'],
#  ['antioxydant juice', 'muffins'],
#  ['antioxydant juice', 'olive oil'],
#  ['antioxydant juice', 'chicken'],
#  ['antioxydant juice', 'salad'],
#  ['antioxydant juice', 'oil'],
#  ['antioxydant juice', 'chocolate'],
#  ['antioxydant juice', 'fresh tuna'],
#  ['antioxydant juice', 'ground beef'],
#  ['antioxydant juice', 'chili'],
#  ['grated cheese', 'herb & pepper'],
#  ['grated cheese', 'mineral water'],
#  ['grated cheese', 'light cream'],
#  ['grated cheese', 'shallot'],
#  ['grated cheese', 'bramble'],
#  ['grated cheese', 'eggs'],
#  ['grated cheese', 'whole weat flour'],
#  ['grated cheese', 'spaghetti'],
#  ['grated cheese', 'carrots'],
#  ['grated cheese', 'water spray'],
#  ['grated cheese', 'burger sauce'],
#  ['grated cheese', 'cooking oil'],
#  ['grated cheese', 'almonds'],
#  ['grated cheese', 'hand protein bar'],
#  ['grated cheese', 'black tea'],
#  ['grated cheese', 'strawberries'],
#  ['grated cheese', 'mint green tea'],
#  ['grated cheese', 'napkins'],
#  ['grated cheese', 'gums'],
#  ['grated cheese', 'vegetables mix'],
#  ['grated cheese', 'asparagus'],
#  ['grated cheese', 'pasta'],
#  ['grated cheese', 'chocolate bread'],
#  ['grated cheese', 'tea'],
#  ['grated cheese', 'whole wheat pasta'],
#  ['grated cheese', 'extra dark chocolate'],
#  ['grated cheese', 'zucchini'],
#  ['grated cheese', 'butter'],
#  ['grated cheese', 'cauliflower'],
#  ['grated cheese', 'protein bar'],
#  ['grated cheese', 'turkey'],
#  ['grated cheese', 'low fat yogurt'],
#  ['grated cheese', 'barbecue sauce'],
#  ['grated cheese', 'champagne'],
#  ['grated cheese', 'mushroom cream sauce'],
#  ['grated cheese', 'dessert wine'],
#  ['grated cheese', 'energy bar'],
#  ['grated cheese', 'parmesan cheese'],
#  ['grated cheese', 'magazines'],
#  ['grated cheese', 'pickles'],
#  ['grated cheese', 'mashed potato'],
#  ['grated cheese', 'green tea'],
#  ['grated cheese', 'light mayo'],
#  ['grated cheese', 'avocado'],
#  ['grated cheese', 'sandwich'],
#  ['grated cheese', 'bug spray'],
#  ['grated cheese', 'frozen smoothie'],
#  ['grated cheese', 'flax seed'],
#  ['grated cheese', 'burgers'],
#  ['grated cheese', 'fresh bread'],
#  ['grated cheese', 'yams'],
#  ['grated cheese', 'blueberries'],
#  ['grated cheese', 'shampoo'],
#  ['grated cheese', 'whole wheat rice'],
#  ['grated cheese', 'body spray'],
#  ['grated cheese', 'energy drink'],
#  ['grated cheese', 'hot dogs'],
#  ['grated cheese', 'oatmeal'],
#  ['grated cheese', 'tomato juice'],
#  ['grated cheese', 'pet food'],
#  ['grated cheese', 'clothes accessories'],
#  ['grated cheese', 'mayonnaise'],
#  ['grated cheese', 'meatballs'],
#  ['grated cheese', 'shrimp'],
#  ['grated cheese', 'babies food'],
#  ['grated cheese', 'nonfat milk'],
#  ['grated cheese', 'bacon'],
#  ['grated cheese', 'cereals'],
#  ['grated cheese', 'honey'],
#  ['grated cheese', 'soda'],
#  ['grated cheese', 'yogurt cake'],
#  ['grated cheese', 'salmon'],
#  ['grated cheese', 'brownies'],
#  ['grated cheese', 'green grapes'],
#  ['grated cheese', 'pepper'],
#  ['grated cheese', 'white wine'],
#  ['grated cheese', 'soup'],
#  ['grated cheese', 'mint'],
#  ['grated cheese', 'ham'],
#  ['grated cheese', 'cream'],
#  ['grated cheese', 'tomatoes'],
#  ['grated cheese', 'cake'],
#  ['grated cheese', 'toothpaste'],
#  ['grated cheese', 'frozen vegetables'],
#  ['grated cheese', 'sparkling water'],
#  ['grated cheese', 'green beans'],
#  ['grated cheese', 'cottage cheese'],
#  ['grated cheese', 'strong cheese'],
#  ['grated cheese', 'french wine'],
#  ['grated cheese', 'french fries'],
#  ['grated cheese', 'cookies'],
#  ['grated cheese', 'fromage blanc'],
#  ['grated cheese', 'ketchup'],
#  ['grated cheese', ' asparagus'],
#  ['grated cheese', 'eggplant'],
#  ['grated cheese', 'spinach'],
#  ['grated cheese', 'chutney'],
#  ['grated cheese', 'salt'],
#  ['grated cheese', 'rice'],
#  ['grated cheese', 'escalope'],
#  ['grated cheese', 'corn'],
#  ['grated cheese', 'cider'],
#  ['grated cheese', 'candy bars'],
#  ['grated cheese', 'melons'],
#  ['grated cheese', 'milk'],
#  ['grated cheese', 'pancakes'],
#  ['grated cheese', 'gluten free bar'],
#  ['grated cheese', 'tomato sauce'],
#  ['grated cheese', 'muffins'],
#  ['grated cheese', 'olive oil'],
#  ['grated cheese', 'chicken'],
#  ['grated cheese', 'salad'],
#  ['grated cheese', 'oil'],
#  ['grated cheese', 'chocolate'],
#  ['grated cheese', 'fresh tuna'],
#  ['grated cheese', 'ground beef'],
#  ['grated cheese', 'chili'],
#  ['herb & pepper', 'mineral water'],
#  ['herb & pepper', 'light cream'],
#  ['herb & pepper', 'shallot'],
#  ['herb & pepper', 'bramble'],
#  ['herb & pepper', 'eggs'],
#  ['herb & pepper', 'whole weat flour'],
#  ['herb & pepper', 'spaghetti'],
#  ['herb & pepper', 'carrots'],
#  ['herb & pepper', 'water spray'],
#  ['herb & pepper', 'burger sauce'],
#  ['herb & pepper', 'cooking oil'],
#  ['herb & pepper', 'almonds'],
#  ['herb & pepper', 'hand protein bar'],
#  ['herb & pepper', 'black tea'],
#  ['herb & pepper', 'strawberries'],
#  ['herb & pepper', 'mint green tea'],
#  ['herb & pepper', 'napkins'],
#  ['herb & pepper', 'gums'],
#  ['herb & pepper', 'vegetables mix'],
#  ['herb & pepper', 'asparagus'],
#  ['herb & pepper', 'pasta'],
#  ['herb & pepper', 'chocolate bread'],
#  ['herb & pepper', 'tea'],
#  ['herb & pepper', 'whole wheat pasta'],
#  ['herb & pepper', 'extra dark chocolate'],
#  ['herb & pepper', 'zucchini'],
#  ['herb & pepper', 'butter'],
#  ['herb & pepper', 'cauliflower'],
#  ['herb & pepper', 'protein bar'],
#  ['herb & pepper', 'turkey'],
#  ['herb & pepper', 'low fat yogurt'],
#  ['herb & pepper', 'barbecue sauce'],
#  ['herb & pepper', 'champagne'],
#  ['herb & pepper', 'mushroom cream sauce'],
#  ['herb & pepper', 'dessert wine'],
#  ['herb & pepper', 'energy bar'],
#  ['herb & pepper', 'parmesan cheese'],
#  ['herb & pepper', 'magazines'],
#  ['herb & pepper', 'pickles'],
#  ['herb & pepper', 'mashed potato'],
#  ['herb & pepper', 'green tea'],
#  ['herb & pepper', 'light mayo'],
#  ['herb & pepper', 'avocado'],
#  ['herb & pepper', 'sandwich'],
#  ['herb & pepper', 'bug spray'],
#  ['herb & pepper', 'frozen smoothie'],
#  ['herb & pepper', 'flax seed'],
#  ['herb & pepper', 'burgers'],
#  ['herb & pepper', 'fresh bread'],
#  ['herb & pepper', 'yams'],
#  ['herb & pepper', 'blueberries'],
#  ['herb & pepper', 'shampoo'],
#  ['herb & pepper', 'whole wheat rice'],
#  ['herb & pepper', 'body spray'],
#  ['herb & pepper', 'energy drink'],
#  ['herb & pepper', 'hot dogs'],
#  ['herb & pepper', 'oatmeal'],
#  ['herb & pepper', 'tomato juice'],
#  ['herb & pepper', 'pet food'],
#  ['herb & pepper', 'clothes accessories'],
#  ['herb & pepper', 'mayonnaise'],
#  ['herb & pepper', 'meatballs'],
#  ['herb & pepper', 'shrimp'],
#  ['herb & pepper', 'babies food'],
#  ['herb & pepper', 'nonfat milk'],
#  ['herb & pepper', 'bacon'],
#  ['herb & pepper', 'cereals'],
#  ['herb & pepper', 'honey'],
#  ['herb & pepper', 'soda'],
#  ['herb & pepper', 'yogurt cake'],
#  ['herb & pepper', 'salmon'],
#  ['herb & pepper', 'brownies'],
#  ['herb & pepper', 'green grapes'],
#  ['herb & pepper', 'pepper'],
#  ['herb & pepper', 'white wine'],
#  ['herb & pepper', 'soup'],
#  ['herb & pepper', 'mint'],
#  ['herb & pepper', 'ham'],
#  ['herb & pepper', 'cream'],
#  ['herb & pepper', 'tomatoes'],
#  ['herb & pepper', 'cake'],
#  ['herb & pepper', 'toothpaste'],
#  ['herb & pepper', 'frozen vegetables'],
#  ['herb & pepper', 'sparkling water'],
#  ['herb & pepper', 'green beans'],
#  ['herb & pepper', 'cottage cheese'],
#  ['herb & pepper', 'strong cheese'],
#  ['herb & pepper', 'french wine'],
#  ['herb & pepper', 'french fries'],
#  ['herb & pepper', 'cookies'],
#  ['herb & pepper', 'fromage blanc'],
#  ['herb & pepper', 'ketchup'],
#  ['herb & pepper', ' asparagus'],
#  ['herb & pepper', 'eggplant'],
#  ['herb & pepper', 'spinach'],
#  ['herb & pepper', 'chutney'],
#  ['herb & pepper', 'salt'],
#  ['herb & pepper', 'rice'],
#  ['herb & pepper', 'escalope'],
#  ['herb & pepper', 'corn'],
#  ['herb & pepper', 'cider'],
#  ['herb & pepper', 'candy bars'],
#  ['herb & pepper', 'melons'],
#  ['herb & pepper', 'milk'],
#  ['herb & pepper', 'pancakes'],
#  ['herb & pepper', 'gluten free bar'],
#  ['herb & pepper', 'tomato sauce'],
#  ['herb & pepper', 'muffins'],
#  ['herb & pepper', 'olive oil'],
#  ['herb & pepper', 'chicken'],
#  ['herb & pepper', 'salad'],
#  ['herb & pepper', 'oil'],
#  ['herb & pepper', 'chocolate'],
#  ['herb & pepper', 'fresh tuna'],
#  ['herb & pepper', 'ground beef'],
#  ['herb & pepper', 'chili'],
#  ['mineral water', 'light cream'],
#  ['mineral water', 'shallot'],
#  ['mineral water', 'bramble'],
#  ['mineral water', 'eggs'],
#  ['mineral water', 'whole weat flour'],
#  ['mineral water', 'spaghetti'],
#  ['mineral water', 'carrots'],
#  ['mineral water', 'water spray'],
#  ['mineral water', 'burger sauce'],
#  ['mineral water', 'cooking oil'],
#  ['mineral water', 'almonds'],
#  ['mineral water', 'hand protein bar'],
#  ['mineral water', 'black tea'],
#  ['mineral water', 'strawberries'],
#  ['mineral water', 'mint green tea'],
#  ['mineral water', 'napkins'],
#  ['mineral water', 'gums'],
#  ['mineral water', 'vegetables mix'],
#  ['mineral water', 'asparagus'],
#  ['mineral water', 'pasta'],
#  ['mineral water', 'chocolate bread'],
#  ['mineral water', 'tea'],
#  ['mineral water', 'whole wheat pasta'],
#  ['mineral water', 'extra dark chocolate'],
#  ['mineral water', 'zucchini'],
#  ['mineral water', 'butter'],
#  ['mineral water', 'cauliflower'],
#  ['mineral water', 'protein bar'],
#  ['mineral water', 'turkey'],
#  ['mineral water', 'low fat yogurt'],
#  ['mineral water', 'barbecue sauce'],
#  ['mineral water', 'champagne'],
#  ['mineral water', 'mushroom cream sauce'],
#  ['mineral water', 'dessert wine'],
#  ['mineral water', 'energy bar'],
#  ['mineral water', 'parmesan cheese'],
#  ['mineral water', 'magazines'],
#  ['mineral water', 'pickles'],
#  ['mineral water', 'mashed potato'],
#  ['mineral water', 'green tea'],
#  ['mineral water', 'light mayo'],
#  ['mineral water', 'avocado'],
#  ['mineral water', 'sandwich'],
#  ['mineral water', 'bug spray'],
#  ['mineral water', 'frozen smoothie'],
#  ['mineral water', 'flax seed'],
#  ['mineral water', 'burgers'],
#  ['mineral water', 'fresh bread'],
#  ['mineral water', 'yams'],
#  ['mineral water', 'blueberries'],
#  ['mineral water', 'shampoo'],
#  ['mineral water', 'whole wheat rice'],
#  ['mineral water', 'body spray'],
#  ['mineral water', 'energy drink'],
#  ['mineral water', 'hot dogs'],
#  ['mineral water', 'oatmeal'],
#  ['mineral water', 'tomato juice'],
#  ['mineral water', 'pet food'],
#  ['mineral water', 'clothes accessories'],
#  ['mineral water', 'mayonnaise'],
#  ['mineral water', 'meatballs'],
#  ['mineral water', 'shrimp'],
#  ['mineral water', 'babies food'],
#  ['mineral water', 'nonfat milk'],
#  ['mineral water', 'bacon'],
#  ['mineral water', 'cereals'],
#  ['mineral water', 'honey'],
#  ['mineral water', 'soda'],
#  ['mineral water', 'yogurt cake'],
#  ['mineral water', 'salmon'],
#  ['mineral water', 'brownies'],
#  ['mineral water', 'green grapes'],
#  ['mineral water', 'pepper'],
#  ['mineral water', 'white wine'],
#  ['mineral water', 'soup'],
#  ['mineral water', 'mint'],
#  ['mineral water', 'ham'],
#  ['mineral water', 'cream'],
#  ['mineral water', 'tomatoes'],
#  ['mineral water', 'cake'],
#  ['mineral water', 'toothpaste'],
#  ['mineral water', 'frozen vegetables'],
#  ['mineral water', 'sparkling water'],
#  ['mineral water', 'green beans'],
#  ['mineral water', 'cottage cheese'],
#  ['mineral water', 'strong cheese'],
#  ['mineral water', 'french wine'],
#  ['mineral water', 'french fries'],
#  ['mineral water', 'cookies'],
#  ['mineral water', 'fromage blanc'],
#  ['mineral water', 'ketchup'],
#  ['mineral water', ' asparagus'],
#  ['mineral water', 'eggplant'],
#  ['mineral water', 'spinach'],
#  ['mineral water', 'chutney'],
#  ['mineral water', 'salt'],
#  ['mineral water', 'rice'],
#  ['mineral water', 'escalope'],
#  ['mineral water', 'corn'],
#  ['mineral water', 'cider'],
#  ['mineral water', 'candy bars'],
#  ['mineral water', 'melons'],
#  ['mineral water', 'milk'],
#  ['mineral water', 'pancakes'],
#  ['mineral water', 'gluten free bar'],
#  ['mineral water', 'tomato sauce'],
#  ['mineral water', 'muffins'],
#  ['mineral water', 'olive oil'],
#  ['mineral water', 'chicken'],
#  ['mineral water', 'salad'],
#  ['mineral water', 'oil'],
#  ['mineral water', 'chocolate'],
#  ['mineral water', 'fresh tuna'],
#  ['mineral water', 'ground beef'],
#  ['mineral water', 'chili'],
#  ['light cream', 'shallot'],
#  ['light cream', 'bramble'],
#  ['light cream', 'eggs'],
#  ['light cream', 'whole weat flour'],
#  ['light cream', 'spaghetti'],
#  ['light cream', 'carrots'],
#  ['light cream', 'water spray'],
#  ['light cream', 'burger sauce'],
#  ['light cream', 'cooking oil'],
#  ['light cream', 'almonds'],
#  ['light cream', 'hand protein bar'],
#  ['light cream', 'black tea'],
#  ['light cream', 'strawberries'],
#  ['light cream', 'mint green tea'],
#  ['light cream', 'napkins'],
#  ['light cream', 'gums'],
#  ['light cream', 'vegetables mix'],
#  ['light cream', 'asparagus'],
#  ['light cream', 'pasta'],
#  ['light cream', 'chocolate bread'],
#  ['light cream', 'tea'],
#  ['light cream', 'whole wheat pasta'],
#  ['light cream', 'extra dark chocolate'],
#  ['light cream', 'zucchini'],
#  ['light cream', 'butter'],
#  ['light cream', 'cauliflower'],
#  ['light cream', 'protein bar'],
#  ['light cream', 'turkey'],
#  ['light cream', 'low fat yogurt'],
#  ['light cream', 'barbecue sauce'],
#  ['light cream', 'champagne'],
#  ['light cream', 'mushroom cream sauce'],
#  ['light cream', 'dessert wine'],
#  ['light cream', 'energy bar'],
#  ['light cream', 'parmesan cheese'],
#  ['light cream', 'magazines'],
#  ['light cream', 'pickles'],
#  ['light cream', 'mashed potato'],
#  ['light cream', 'green tea'],
#  ['light cream', 'light mayo'],
#  ['light cream', 'avocado'],
#  ['light cream', 'sandwich'],
#  ['light cream', 'bug spray'],
#  ['light cream', 'frozen smoothie'],
#  ['light cream', 'flax seed'],
#  ['light cream', 'burgers'],
#  ['light cream', 'fresh bread'],
#  ['light cream', 'yams'],
#  ['light cream', 'blueberries'],
#  ['light cream', 'shampoo'],
#  ['light cream', 'whole wheat rice'],
#  ['light cream', 'body spray'],
#  ['light cream', 'energy drink'],
#  ['light cream', 'hot dogs'],
#  ['light cream', 'oatmeal'],
#  ['light cream', 'tomato juice'],
#  ['light cream', 'pet food'],
#  ['light cream', 'clothes accessories'],
#  ['light cream', 'mayonnaise'],
#  ['light cream', 'meatballs'],
#  ['light cream', 'shrimp'],
#  ['light cream', 'babies food'],
#  ['light cream', 'nonfat milk'],
#  ['light cream', 'bacon'],
#  ['light cream', 'cereals'],
#  ['light cream', 'honey'],
#  ['light cream', 'soda'],
#  ['light cream', 'yogurt cake'],
#  ['light cream', 'salmon'],
#  ['light cream', 'brownies'],
#  ['light cream', 'green grapes'],
#  ['light cream', 'pepper'],
#  ['light cream', 'white wine'],
#  ['light cream', 'soup'],
#  ['light cream', 'mint'],
#  ['light cream', 'ham'],
#  ['light cream', 'cream'],
#  ['light cream', 'tomatoes'],
#  ['light cream', 'cake'],
#  ['light cream', 'toothpaste'],
#  ['light cream', 'frozen vegetables'],
#  ['light cream', 'sparkling water'],
#  ['light cream', 'green beans'],
#  ['light cream', 'cottage cheese'],
#  ['light cream', 'strong cheese'],
#  ['light cream', 'french wine'],
#  ['light cream', 'french fries'],
#  ['light cream', 'cookies'],
#  ['light cream', 'fromage blanc'],
#  ['light cream', 'ketchup'],
#  ['light cream', ' asparagus'],
#  ['light cream', 'eggplant'],
#  ['light cream', 'spinach'],
#  ['light cream', 'chutney'],
#  ['light cream', 'salt'],
#  ['light cream', 'rice'],
#  ['light cream', 'escalope'],
#  ['light cream', 'corn'],
#  ['light cream', 'cider'],
#  ['light cream', 'candy bars'],
#  ['light cream', 'melons'],
#  ['light cream', 'milk'],
#  ['light cream', 'pancakes'],
#  ['light cream', 'gluten free bar'],
#  ['light cream', 'tomato sauce'],
#  ['light cream', 'muffins'],
#  ['light cream', 'olive oil'],
#  ['light cream', 'chicken'],
#  ['light cream', 'salad'],
#  ['light cream', 'oil'],
#  ['light cream', 'chocolate'],
#  ['light cream', 'fresh tuna'],
#  ['light cream', 'ground beef'],
#  ['light cream', 'chili'],
#  ['shallot', 'bramble'],
#  ['shallot', 'eggs'],
#  ['shallot', 'whole weat flour'],
#  ['shallot', 'spaghetti'],
#  ['shallot', 'carrots'],
#  ['shallot', 'water spray'],
#  ['shallot', 'burger sauce'],
#  ['shallot', 'cooking oil'],
#  ['shallot', 'almonds'],
#  ['shallot', 'hand protein bar'],
#  ['shallot', 'black tea'],
#  ['shallot', 'strawberries'],
#  ['shallot', 'mint green tea'],
#  ['shallot', 'napkins'],
#  ['shallot', 'gums'],
#  ['shallot', 'vegetables mix'],
#  ['shallot', 'asparagus'],
#  ['shallot', 'pasta'],
#  ['shallot', 'chocolate bread'],
#  ['shallot', 'tea'],
#  ['shallot', 'whole wheat pasta'],
#  ['shallot', 'extra dark chocolate'],
#  ['shallot', 'zucchini'],
#  ['shallot', 'butter'],
#  ['shallot', 'cauliflower'],
#  ['shallot', 'protein bar'],
#  ['shallot', 'turkey'],
#  ['shallot', 'low fat yogurt'],
#  ['shallot', 'barbecue sauce'],
#  ['shallot', 'champagne'],
#  ['shallot', 'mushroom cream sauce'],
#  ['shallot', 'dessert wine'],
#  ['shallot', 'energy bar'],
#  ['shallot', 'parmesan cheese'],
#  ['shallot', 'magazines'],
#  ['shallot', 'pickles'],
#  ['shallot', 'mashed potato'],
#  ['shallot', 'green tea'],
#  ['shallot', 'light mayo'],
#  ['shallot', 'avocado'],
#  ['shallot', 'sandwich'],
#  ['shallot', 'bug spray'],
#  ['shallot', 'frozen smoothie'],
#  ['shallot', 'flax seed'],
#  ['shallot', 'burgers'],
#  ['shallot', 'fresh bread'],
#  ['shallot', 'yams'],
#  ['shallot', 'blueberries'],
#  ['shallot', 'shampoo'],
#  ['shallot', 'whole wheat rice'],
#  ['shallot', 'body spray'],
#  ['shallot', 'energy drink'],
#  ['shallot', 'hot dogs'],
#  ['shallot', 'oatmeal'],
#  ['shallot', 'tomato juice'],
#  ['shallot', 'pet food'],
#  ['shallot', 'clothes accessories'],
#  ['shallot', 'mayonnaise'],
#  ['shallot', 'meatballs'],
#  ['shallot', 'shrimp'],
#  ['shallot', 'babies food'],
#  ['shallot', 'nonfat milk'],
#  ['shallot', 'bacon'],
#  ['shallot', 'cereals'],
#  ['shallot', 'honey'],
#  ['shallot', 'soda'],
#  ['shallot', 'yogurt cake'],
#  ['shallot', 'salmon'],
#  ['shallot', 'brownies'],
#  ['shallot', 'green grapes'],
#  ['shallot', 'pepper'],
#  ['shallot', 'white wine'],
#  ['shallot', 'soup'],
#  ['shallot', 'mint'],
#  ['shallot', 'ham'],
#  ['shallot', 'cream'],
#  ['shallot', 'tomatoes'],
#  ['shallot', 'cake'],
#  ['shallot', 'toothpaste'],
#  ['shallot', 'frozen vegetables'],
#  ['shallot', 'sparkling water'],
#  ['shallot', 'green beans'],
#  ['shallot', 'cottage cheese'],
#  ['shallot', 'strong cheese'],
#  ['shallot', 'french wine'],
#  ['shallot', 'french fries'],
#  ['shallot', 'cookies'],
#  ['shallot', 'fromage blanc'],
#  ['shallot', 'ketchup'],
#  ['shallot', ' asparagus'],
#  ['shallot', 'eggplant'],
#  ['shallot', 'spinach'],
#  ['shallot', 'chutney'],
#  ['shallot', 'salt'],
#  ['shallot', 'rice'],
#  ['shallot', 'escalope'],
#  ['shallot', 'corn'],
#  ['shallot', 'cider'],
#  ['shallot', 'candy bars'],
#  ['shallot', 'melons'],
#  ['shallot', 'milk'],
#  ['shallot', 'pancakes'],
#  ['shallot', 'gluten free bar'],
#  ['shallot', 'tomato sauce'],
#  ['shallot', 'muffins'],
#  ['shallot', 'olive oil'],
#  ['shallot', 'chicken'],
#  ['shallot', 'salad'],
#  ['shallot', 'oil'],
#  ['shallot', 'chocolate'],
#  ['shallot', 'fresh tuna'],
#  ['shallot', 'ground beef'],
#  ['shallot', 'chili'],
#  ['bramble', 'eggs'],
#  ['bramble', 'whole weat flour'],
#  ['bramble', 'spaghetti'],
#  ['bramble', 'carrots'],
#  ['bramble', 'water spray'],
#  ['bramble', 'burger sauce'],
#  ['bramble', 'cooking oil'],
#  ['bramble', 'almonds'],
#  ['bramble', 'hand protein bar'],
#  ['bramble', 'black tea'],
#  ['bramble', 'strawberries'],
#  ['bramble', 'mint green tea'],
#  ['bramble', 'napkins'],
#  ['bramble', 'gums'],
#  ['bramble', 'vegetables mix'],
#  ['bramble', 'asparagus'],
#  ['bramble', 'pasta'],
#  ['bramble', 'chocolate bread'],
#  ['bramble', 'tea'],
#  ['bramble', 'whole wheat pasta'],
#  ['bramble', 'extra dark chocolate'],
#  ['bramble', 'zucchini'],
#  ['bramble', 'butter'],
#  ['bramble', 'cauliflower'],
#  ['bramble', 'protein bar'],
#  ['bramble', 'turkey'],
#  ['bramble', 'low fat yogurt'],
#  ['bramble', 'barbecue sauce'],
#  ['bramble', 'champagne'],
#  ['bramble', 'mushroom cream sauce'],
#  ['bramble', 'dessert wine'],
#  ['bramble', 'energy bar'],
#  ['bramble', 'parmesan cheese'],
#  ['bramble', 'magazines'],
#  ['bramble', 'pickles'],
#  ['bramble', 'mashed potato'],
#  ['bramble', 'green tea'],
#  ['bramble', 'light mayo'],
#  ['bramble', 'avocado'],
#  ['bramble', 'sandwich'],
#  ['bramble', 'bug spray'],
#  ['bramble', 'frozen smoothie'],
#  ['bramble', 'flax seed'],
#  ['bramble', 'burgers'],
#  ['bramble', 'fresh bread'],
#  ['bramble', 'yams'],
#  ['bramble', 'blueberries'],
#  ['bramble', 'shampoo'],
#  ['bramble', 'whole wheat rice'],
#  ['bramble', 'body spray'],
#  ['bramble', 'energy drink'],
#  ['bramble', 'hot dogs'],
#  ['bramble', 'oatmeal'],
#  ['bramble', 'tomato juice'],
#  ['bramble', 'pet food'],
#  ['bramble', 'clothes accessories'],
#  ['bramble', 'mayonnaise'],
#  ['bramble', 'meatballs'],
#  ['bramble', 'shrimp'],
#  ['bramble', 'babies food'],
#  ['bramble', 'nonfat milk'],
#  ['bramble', 'bacon'],
#  ['bramble', 'cereals'],
#  ['bramble', 'honey'],
#  ['bramble', 'soda'],
#  ['bramble', 'yogurt cake'],
#  ['bramble', 'salmon'],
#  ['bramble', 'brownies'],
#  ['bramble', 'green grapes'],
#  ['bramble', 'pepper'],
#  ['bramble', 'white wine'],
#  ['bramble', 'soup'],
#  ['bramble', 'mint'],
#  ['bramble', 'ham'],
#  ['bramble', 'cream'],
#  ['bramble', 'tomatoes'],
#  ['bramble', 'cake'],
#  ['bramble', 'toothpaste'],
#  ['bramble', 'frozen vegetables'],
#  ['bramble', 'sparkling water'],
#  ['bramble', 'green beans'],
#  ['bramble', 'cottage cheese'],
#  ['bramble', 'strong cheese'],
#  ['bramble', 'french wine'],
#  ['bramble', 'french fries'],
#  ['bramble', 'cookies'],
#  ['bramble', 'fromage blanc'],
#  ['bramble', 'ketchup'],
#  ['bramble', ' asparagus'],
#  ['bramble', 'eggplant'],
#  ['bramble', 'spinach'],
#  ['bramble', 'chutney'],
#  ['bramble', 'salt'],
#  ['bramble', 'rice'],
#  ['bramble', 'escalope'],
#  ['bramble', 'corn'],
#  ['bramble', 'cider'],
#  ['bramble', 'candy bars'],
#  ['bramble', 'melons'],
#  ['bramble', 'milk'],
#  ['bramble', 'pancakes'],
#  ['bramble', 'gluten free bar'],
#  ['bramble', 'tomato sauce'],
#  ['bramble', 'muffins'],
#  ['bramble', 'olive oil'],
#  ['bramble', 'chicken'],
#  ['bramble', 'salad'],
#  ['bramble', 'oil'],
#  ['bramble', 'chocolate'],
#  ['bramble', 'fresh tuna'],
#  ['bramble', 'ground beef'],
#  ['bramble', 'chili'],
#  ['eggs', 'whole weat flour'],
#  ['eggs', 'spaghetti'],
#  ['eggs', 'carrots'],
#  ['eggs', 'water spray'],
#  ['eggs', 'burger sauce'],
#  ['eggs', 'cooking oil'],
#  ['eggs', 'almonds'],
#  ['eggs', 'hand protein bar'],
#  ['eggs', 'black tea'],
#  ['eggs', 'strawberries'],
#  ['eggs', 'mint green tea'],
#  ['eggs', 'napkins'],
#  ['eggs', 'gums'],
#  ['eggs', 'vegetables mix'],
#  ['eggs', 'asparagus'],
#  ['eggs', 'pasta'],
#  ['eggs', 'chocolate bread'],
#  ['eggs', 'tea'],
#  ['eggs', 'whole wheat pasta'],
#  ['eggs', 'extra dark chocolate'],
#  ['eggs', 'zucchini'],
#  ['eggs', 'butter'],
#  ['eggs', 'cauliflower'],
#  ['eggs', 'protein bar'],
#  ['eggs', 'turkey'],
#  ['eggs', 'low fat yogurt'],
#  ['eggs', 'barbecue sauce'],
#  ['eggs', 'champagne'],
#  ['eggs', 'mushroom cream sauce'],
#  ['eggs', 'dessert wine'],
#  ['eggs', 'energy bar'],
#  ['eggs', 'parmesan cheese'],
#  ['eggs', 'magazines'],
#  ['eggs', 'pickles'],
#  ['eggs', 'mashed potato'],
#  ['eggs', 'green tea'],
#  ['eggs', 'light mayo'],
#  ['eggs', 'avocado'],
#  ['eggs', 'sandwich'],
#  ['eggs', 'bug spray'],
#  ['eggs', 'frozen smoothie'],
#  ['eggs', 'flax seed'],
#  ['eggs', 'burgers'],
#  ['eggs', 'fresh bread'],
#  ['eggs', 'yams'],
#  ['eggs', 'blueberries'],
#  ['eggs', 'shampoo'],
#  ['eggs', 'whole wheat rice'],
#  ['eggs', 'body spray'],
#  ['eggs', 'energy drink'],
#  ['eggs', 'hot dogs'],
#  ['eggs', 'oatmeal'],
#  ['eggs', 'tomato juice'],
#  ['eggs', 'pet food'],
#  ['eggs', 'clothes accessories'],
#  ['eggs', 'mayonnaise'],
#  ['eggs', 'meatballs'],
#  ['eggs', 'shrimp'],
#  ['eggs', 'babies food'],
#  ['eggs', 'nonfat milk'],
#  ['eggs', 'bacon'],
#  ['eggs', 'cereals'],
#  ['eggs', 'honey'],
#  ['eggs', 'soda'],
#  ['eggs', 'yogurt cake'],
#  ['eggs', 'salmon'],
#  ['eggs', 'brownies'],
#  ['eggs', 'green grapes'],
#  ['eggs', 'pepper'],
#  ['eggs', 'white wine'],
#  ['eggs', 'soup'],
#  ['eggs', 'mint'],
#  ['eggs', 'ham'],
#  ['eggs', 'cream'],
#  ['eggs', 'tomatoes'],
#  ['eggs', 'cake'],
#  ...]

# %% [markdown]
# #### Calculating score
# The calculation is done looking at the number of customers that bought both items (the pair) and divided by all customers of the week (7501). This calculation is done for all pairs possible and the score is returned on "score" list.
#
# $ score = \frac{\text{number of lists that contain [item x and item y]}} {\text{number of all lists}} $

# %%
# %%time
score = []
for i in pair:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    #mycode = "print 'hello world'"
    score.append(len(eval(mycode))/7501.)
# Out:
# Wall time: 14 s

# %% [markdown]
# #### Showing results
#
# Top 10 Most common pairs of items of this week

# %%
ranking_ECLAT = pd.DataFrame([pair, score]).transpose()
ranking_ECLAT.columns = ['Pair', 'Score']

# %%
ranking_ECLAT.sort_values('Score', ascending=False).head(10)
# Out:
#                                     Pair     Score
# 475           [mineral water, spaghetti]  0.059725
# 581           [mineral water, chocolate]   0.05266
# 473                [mineral water, eggs]  0.050927
# 572                [mineral water, milk]  0.047994
# 583         [mineral water, ground beef]  0.040928
# 1252            [spaghetti, ground beef]  0.039195
# 1250              [spaghetti, chocolate]  0.039195
# 925                    [eggs, spaghetti]  0.036528
# 1007                [eggs, french fries]  0.036395
# 551   [mineral water, frozen vegetables]  0.035729

# %% [markdown]
# ### What if we do that for trios?

# %%
# Creating trios
trio = []
for j in range(0, len(uniqueItems)):
    for k in range(j, len(uniqueItems)):
        for l in range(k, len(uniqueItems)):
            if (k != j) and (j != l) and (k != l):
                try:
                    trio.append([uniqueItems[j], uniqueItems[j+k], uniqueItems[j+l]])
                except IndexError:
                    pass

# %%
trio[:5]
# Out:
# [['red wine', 'antioxydant juice', 'grated cheese'],
#  ['red wine', 'antioxydant juice', 'herb & pepper'],
#  ['red wine', 'antioxydant juice', 'mineral water'],
#  ['red wine', 'antioxydant juice', 'light cream'],
#  ['red wine', 'antioxydant juice', 'shallot']]

# %%
# %%time
score_trio = []
for i in trio:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    #mycode = "print 'hello world'"
    score_trio.append(len(eval(mycode))/7501.)
# Out:
# Wall time: 4min 35s

# %%
ranking_ECLAT_trio = pd.DataFrame([trio, score_trio]).transpose()
ranking_ECLAT_trio.columns = ['Trio', 'Score']
ranking_ECLAT_trio.sort_values('Score', ascending=False).head(10)
# Out:
#                                                 Trio     Score
# 26907        [mineral water, spaghetti, ground beef]  0.017064
# 26905          [mineral water, spaghetti, chocolate]  0.015865
# 26896               [mineral water, spaghetti, milk]  0.015731
# 32725               [mineral water, milk, chocolate]  0.013998
# 26875  [mineral water, spaghetti, frozen vegetables]  0.011998
# 26897           [mineral water, spaghetti, pancakes]  0.011465
# 32727             [mineral water, milk, ground beef]  0.011065
# 32254       [mineral water, frozen vegetables, milk]  0.011065
# 64896                   [spaghetti, milk, chocolate]  0.010932
# 32790        [mineral water, chocolate, ground beef]  0.010932

# %% [markdown]
# ## What about comparing the results from Apriori and ECLAT?

# %% [markdown]
# We got from Apriori that the combination that lead to more "attractiveness power" is "olive oil", "whole wheat pasta" and "mineral water". If we run the ECLAT code for this set of items, we will obtain: 0.0039.
#
# This score of 3 items has not enough score to be placed among top 10, but they are measuring different metrics.  According to apriori these are the items that when picked one lead to another items more frequently than other combinations, i.e. when a person pick 'olive oil', the probability of picking 'whole wheat pasta' and 'mineral water' is much higher than picking another combination. ECLAT in another hand is just sorting as the most common combinations of all lists, not caring about how one item isolatedly can influence in the purchase of another.

# %%
i = ["olive oil", "whole wheat pasta", "mineral water"]
cond = []
for item in i:
    cond.append('("{}") in s'.format(item))
mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
tra = eval(mycode)

# %%
cond
# Out:
# ['("olive oil") in s', '("whole wheat pasta") in s', '("mineral water") in s']

# %%
mycode
# Out:
# '[s for s in transactions if ("olive oil") in s and ("whole wheat pasta") in s and ("mineral water") in s]'

# %%
tra
# Out:
# [['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'almonds',
#   'french wine',
#   'yogurt cake',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'fresh tuna',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'olive oil',
#   'almonds',
#   'cake',
#   'chicken',
#   'extra dark chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'carrots',
#   'protein bar',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'milk',
#   'olive oil',
#   'muffins',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'chicken',
#   'salmon',
#   'pancakes',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'cooking oil',
#   'ketchup',
#   'champagne',
#   'cookies',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'chicken',
#   'gums',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'frozen smoothie',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'herb & pepper',
#   'tomatoes',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'vegetables mix',
#   'pancakes',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'cottage cheese',
#   'energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'turkey',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'eggs',
#   'cake',
#   'cooking oil',
#   'cereals',
#   'french fries',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'chicken',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'frozen smoothie',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'ham',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'honey',
#   'frozen smoothie',
#   'cottage cheese',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'tomatoes',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'bacon',
#   'cake',
#   'gums',
#   'pancakes',
#   'yogurt cake',
#   'tomato juice',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'french wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cake',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'chicken',
#   'white wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'escalope',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'black tea',
#   'salmon',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'cooking oil',
#   'low fat yogurt',
#   'zucchini',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
print ('Score for "olive oil", "whole wheat pasta", "mineral water": {}'.format(len(tra)/7501.))
# Out:
# Score for "olive oil", "whole wheat pasta", "mineral water": 0.0038661511798426876
