# %% [markdown]
# # Association Rule - Apriori and ECLAT
#
# Training association rule models (Apriori and ECLAT) to find the most related items bought by customers of a french supermarket during a week. All 7501 lines of the dataset represent items bought by an unique customer, during this week.
#
# This algorithm associate products preferences by most of the customers and can be used to generate products recommendation and help on displaying products strategy.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data Loading
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# Adding all customers into a list of lists
transactions = []
for i in range(0, len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
dataset.head(20)
# Out:
#                    0             1              2                 3   \
# 0              shrimp       almonds        avocado    vegetables mix
# 1             burgers     meatballs           eggs               NaN
# 2             chutney           NaN            NaN               NaN
# 3              turkey       avocado            NaN               NaN
# 4       mineral water          milk     energy bar  whole wheat rice
# 5      low fat yogurt           NaN            NaN               NaN
# 6   whole wheat pasta  french fries            NaN               NaN
# 7                soup   light cream        shallot               NaN
# 8   frozen vegetables     spaghetti      green tea               NaN
# 9        french fries           NaN            NaN               NaN
# 10               eggs      pet food            NaN               NaN
# 11            cookies           NaN            NaN               NaN
# 12             turkey       burgers  mineral water              eggs
# 13          spaghetti     champagne        cookies               NaN
# 14      mineral water        salmon            NaN               NaN
# 15      mineral water           NaN            NaN               NaN
# 16             shrimp     chocolate        chicken             honey
# 17             turkey          eggs            NaN               NaN
# 18             turkey    fresh tuna       tomatoes         spaghetti
# 19          meatballs          milk          honey      french fries
#
#                4                 5               6               7   \
# 0    green grapes  whole weat flour            yams  cottage cheese
# 1             NaN               NaN             NaN             NaN
# 2             NaN               NaN             NaN             NaN
# 3             NaN               NaN             NaN             NaN
# 4       green tea               NaN             NaN             NaN
# 5             NaN               NaN             NaN             NaN
# 6             NaN               NaN             NaN             NaN
# 7             NaN               NaN             NaN             NaN
# 8             NaN               NaN             NaN             NaN
# 9             NaN               NaN             NaN             NaN
# 10            NaN               NaN             NaN             NaN
# 11            NaN               NaN             NaN             NaN
# 12    cooking oil               NaN             NaN             NaN
# 13            NaN               NaN             NaN             NaN
# 14            NaN               NaN             NaN             NaN
# 15            NaN               NaN             NaN             NaN
# 16            oil       cooking oil  low fat yogurt             NaN
# 17            NaN               NaN             NaN             NaN
# 18  mineral water         black tea          salmon            eggs
# 19    protein bar               NaN             NaN             NaN
#
#               8                     9               10         11     12  \
# 0   energy drink          tomato juice  low fat yogurt  green tea  honey
# 1            NaN                   NaN             NaN        NaN    NaN
# 2            NaN                   NaN             NaN        NaN    NaN
# 3            NaN                   NaN             NaN        NaN    NaN
# 4            NaN                   NaN             NaN        NaN    NaN
# 5            NaN                   NaN             NaN        NaN    NaN
# 6            NaN                   NaN             NaN        NaN    NaN
# 7            NaN                   NaN             NaN        NaN    NaN
# 8            NaN                   NaN             NaN        NaN    NaN
# 9            NaN                   NaN             NaN        NaN    NaN
# 10           NaN                   NaN             NaN        NaN    NaN
# 11           NaN                   NaN             NaN        NaN    NaN
# 12           NaN                   NaN             NaN        NaN    NaN
# 13           NaN                   NaN             NaN        NaN    NaN
# 14           NaN                   NaN             NaN        NaN    NaN
# 15           NaN                   NaN             NaN        NaN    NaN
# 16           NaN                   NaN             NaN        NaN    NaN
# 17           NaN                   NaN             NaN        NaN    NaN
# 18       chicken  extra dark chocolate             NaN        NaN    NaN
# 19           NaN                   NaN             NaN        NaN    NaN
#
#        13             14      15                 16               17       18  \
# 0   salad  mineral water  salmon  antioxydant juice  frozen smoothie  spinach
# 1     NaN            NaN     NaN                NaN              NaN      NaN
# 2     NaN            NaN     NaN                NaN              NaN      NaN
# 3     NaN            NaN     NaN                NaN              NaN      NaN
# 4     NaN            NaN     NaN                NaN              NaN      NaN
# 5     NaN            NaN     NaN                NaN              NaN      NaN
# 6     NaN            NaN     NaN                NaN              NaN      NaN
# 7     NaN            NaN     NaN                NaN              NaN      NaN
# 8     NaN            NaN     NaN                NaN              NaN      NaN
# 9     NaN            NaN     NaN                NaN              NaN      NaN
# 10    NaN            NaN     NaN                NaN              NaN      NaN
# 11    NaN            NaN     NaN                NaN              NaN      NaN
# 12    NaN            NaN     NaN                NaN              NaN      NaN
# 13    NaN            NaN     NaN                NaN              NaN      NaN
# 14    NaN            NaN     NaN                NaN              NaN      NaN
# 15    NaN            NaN     NaN                NaN              NaN      NaN
# 16    NaN            NaN     NaN                NaN              NaN      NaN
# 17    NaN            NaN     NaN                NaN              NaN      NaN
# 18    NaN            NaN     NaN                NaN              NaN      NaN
# 19    NaN            NaN     NaN                NaN              NaN      NaN
#
#            19
# 0   olive oil
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %% [markdown]
# ### Apriori implementation using apyori library
# source: https://github.com/ymoch/apyori
#
# The output of this part is to see which are the products that used to be more bought in combination compared to other combinations using apriori algorithm.
#
# We will put some transformations to fit on dataframes and to make the visualization easier.

# %%
# Inspecting elements
transactions[:3]
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
# Training Apriori on the dataset
# The hyperparameters choosen on this training are:
# min_support = items bought more than 3 times a day * 7 days (week) / 7500 customers = 0.0028
# min_confidence: at least 20%, min_lift = minimum of 3 (less than that is too low)
# min_length: we want at least 2 items to be associated. No point in having a single item in the result

from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
# Visualising the results
results = list(rules)

# %%
lift = []
association = []
for i in range (0, len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %% [markdown]
# ### Visualizing results in a dataframe

# %%
rank = pd.DataFrame([association, lift]).transpose()
rank.columns = ['Association', 'Lift']

# %%
# Show top 10 higher lift scores
rank.sort_values('Lift', ascending=False).head(10)
# Out:
#                                            Association      Lift
# 150  [mineral water, nan, frozen vegetables, milk, ...  7.987176
# 97      [mineral water, frozen vegetables, milk, soup]  7.987176
# 149  [mineral water, nan, frozen vegetables, milk, ...  6.128268
# 96   [mineral water, frozen vegetables, milk, olive...  6.128268
# 132  [mineral water, nan, whole wheat pasta, olive ...  6.128268
# 59       [mineral water, whole wheat pasta, olive oil]  6.115863
# 50              [ground beef, tomato sauce, spaghetti]  5.535971
# 122        [nan, ground beef, tomato sauce, spaghetti]  5.535971
# 28                         [nan, honey, fromage blanc]  5.178818
# 3                               [honey, fromage blanc]  5.164271

# %% [markdown]
# By the study, "olive oil, whole wheat pasta, mineral water" are the most commom combined items from this week for the supermarket in question.

# %% [markdown]
# ## ECLAT Implementation
#
# This is an implementation of the ECLAT code by hand. It calculate the pairs that have been bought more frequently comparing to other pairs. At the end, we expect to see what is the most common combination of products during the week.
#
# An extension of the code can calculate the three most common combination, 4, and so on.

# %% [markdown]
# #### Getting the list of products bought this week by all customers

# %%
# Putting all transactions in a single list
itens = []
for i in range(0, len(transactions)):
    itens.extend(transactions[i])

# Finding unique items from transactions and removing nan
uniqueItems = list(set(itens))
uniqueItems.remove('nan')

# %%
uniqueItems
# Out:
# ['salmon',
#  'chocolate bread',
#  'light mayo',
#  'body spray',
#  'ketchup',
#  'bacon',
#  'cauliflower',
#  'oatmeal',
#  'shallot',
#  'chocolate',
#  'protein bar',
#  'green grapes',
#  'mushroom cream sauce',
#  'fromage blanc',
#  'mayonnaise',
#  'antioxydant juice',
#  'ham',
#  'black tea',
#  'herb & pepper',
#  'extra dark chocolate',
#  'meatballs',
#  'pickles',
#  'french wine',
#  'hot dogs',
#  'hand protein bar',
#  'babies food',
#  'whole wheat pasta',
#  'light cream',
#  'muffins',
#  'honey',
#  'white wine',
#  'green tea',
#  'chutney',
#  'chicken',
#  'spinach',
#  'olive oil',
#  'strong cheese',
#  'mineral water',
#  'toothpaste',
#  'nonfat milk',
#  'tomato juice',
#  'cream',
#  'avocado',
#  'red wine',
#  'clothes accessories',
#  'carrots',
#  'eggs',
#  'pancakes',
#  'flax seed',
#  'tomato sauce',
#  'zucchini',
#  'turkey',
#  'vegetables mix',
#  'escalope',
#  'french fries',
#  'melons',
#  'whole weat flour',
#  'yogurt cake',
#  'candy bars',
#  'bug spray',
#  'soda',
#  'low fat yogurt',
#  'pepper',
#  'gluten free bar',
#  ' asparagus',
#  'milk',
#  'tea',
#  'salad',
#  'frozen smoothie',
#  'napkins',
#  'fresh bread',
#  'cake',
#  'bramble',
#  'grated cheese',
#  'gums',
#  'champagne',
#  'rice',
#  'chili',
#  'cookies',
#  'yams',
#  'tomatoes',
#  'pasta',
#  'energy bar',
#  'brownies',
#  'asparagus',
#  'salt',
#  'green beans',
#  'magazines',
#  'energy drink',
#  'shrimp',
#  'burger sauce',
#  'strawberries',
#  'barbecue sauce',
#  'cereals',
#  'mint green tea',
#  'oil',
#  'mint',
#  'cooking oil',
#  'pet food',
#  'shampoo',
#  'fresh tuna',
#  'sandwich',
#  'soup',
#  'spaghetti',
#  'cottage cheese',
#  'sparkling water',
#  'ground beef',
#  'eggplant',
#  'parmesan cheese',
#  'frozen vegetables',
#  'dessert wine',
#  'blueberries',
#  'almonds',
#  'corn',
#  'butter',
#  'water spray',
#  'mashed potato',
#  'cider',
#  'burgers',
#  'whole wheat rice']

# %% [markdown]
# #### Creating combinations with the items - pairs

# %%
pair = []
for j in range(0, len(uniqueItems)):
    k = 1;
    while k <= len(uniqueItems):
        try:
            pair.append([uniqueItems[j], uniqueItems[j+k]])
        except IndexError:
            pass
        k = k + 1;

# %%
pair
# Out:
# [['salmon', 'chocolate bread'],
#  ['salmon', 'light mayo'],
#  ['salmon', 'body spray'],
#  ['salmon', 'ketchup'],
#  ['salmon', 'bacon'],
#  ['salmon', 'cauliflower'],
#  ['salmon', 'oatmeal'],
#  ['salmon', 'shallot'],
#  ['salmon', 'chocolate'],
#  ['salmon', 'protein bar'],
#  ['salmon', 'green grapes'],
#  ['salmon', 'mushroom cream sauce'],
#  ['salmon', 'fromage blanc'],
#  ['salmon', 'mayonnaise'],
#  ['salmon', 'antioxydant juice'],
#  ['salmon', 'ham'],
#  ['salmon', 'black tea'],
#  ['salmon', 'herb & pepper'],
#  ['salmon', 'extra dark chocolate'],
#  ['salmon', 'meatballs'],
#  ['salmon', 'pickles'],
#  ['salmon', 'french wine'],
#  ['salmon', 'hot dogs'],
#  ['salmon', 'hand protein bar'],
#  ['salmon', 'babies food'],
#  ['salmon', 'whole wheat pasta'],
#  ['salmon', 'light cream'],
#  ['salmon', 'muffins'],
#  ['salmon', 'honey'],
#  ['salmon', 'white wine'],
#  ['salmon', 'green tea'],
#  ['salmon', 'chutney'],
#  ['salmon', 'chicken'],
#  ['salmon', 'spinach'],
#  ['salmon', 'olive oil'],
#  ['salmon', 'strong cheese'],
#  ['salmon', 'mineral water'],
#  ['salmon', 'toothpaste'],
#  ['salmon', 'nonfat milk'],
#  ['salmon', 'tomato juice'],
#  ['salmon', 'cream'],
#  ['salmon', 'avocado'],
#  ['salmon', 'red wine'],
#  ['salmon', 'clothes accessories'],
#  ['salmon', 'carrots'],
#  ['salmon', 'eggs'],
#  ['salmon', 'pancakes'],
#  ['salmon', 'flax seed'],
#  ['salmon', 'tomato sauce'],
#  ['salmon', 'zucchini'],
#  ['salmon', 'turkey'],
#  ['salmon', 'vegetables mix'],
#  ['salmon', 'escalope'],
#  ['salmon', 'french fries'],
#  ['salmon', 'melons'],
#  ['salmon', 'whole weat flour'],
#  ['salmon', 'yogurt cake'],
#  ['salmon', 'candy bars'],
#  ['salmon', 'bug spray'],
#  ['salmon', 'soda'],
#  ['salmon', 'low fat yogurt'],
#  ['salmon', 'pepper'],
#  ['salmon', 'gluten free bar'],
#  ['salmon', ' asparagus'],
#  ['salmon', 'milk'],
#  ['salmon', 'tea'],
#  ['salmon', 'salad'],
#  ['salmon', 'frozen smoothie'],
#  ['salmon', 'napkins'],
#  ['salmon', 'fresh bread'],
#  ['salmon', 'cake'],
#  ['salmon', 'bramble'],
#  ['salmon', 'grated cheese'],
#  ['salmon', 'gums'],
#  ['salmon', 'champagne'],
#  ['salmon', 'rice'],
#  ['salmon', 'chili'],
#  ['salmon', 'cookies'],
#  ['salmon', 'yams'],
#  ['salmon', 'tomatoes'],
#  ['salmon', 'pasta'],
#  ['salmon', 'energy bar'],
#  ['salmon', 'brownies'],
#  ['salmon', 'asparagus'],
#  ['salmon', 'salt'],
#  ['salmon', 'green beans'],
#  ['salmon', 'magazines'],
#  ['salmon', 'energy drink'],
#  ['salmon', 'shrimp'],
#  ['salmon', 'burger sauce'],
#  ['salmon', 'strawberries'],
#  ['salmon', 'barbecue sauce'],
#  ['salmon', 'cereals'],
#  ['salmon', 'mint green tea'],
#  ['salmon', 'oil'],
#  ['salmon', 'mint'],
#  ['salmon', 'cooking oil'],
#  ['salmon', 'pet food'],
#  ['salmon', 'shampoo'],
#  ['salmon', 'fresh tuna'],
#  ['salmon', 'sandwich'],
#  ['salmon', 'soup'],
#  ['salmon', 'spaghetti'],
#  ['salmon', 'cottage cheese'],
#  ['salmon', 'sparkling water'],
#  ['salmon', 'ground beef'],
#  ['salmon', 'eggplant'],
#  ['salmon', 'parmesan cheese'],
#  ['salmon', 'frozen vegetables'],
#  ['salmon', 'dessert wine'],
#  ['salmon', 'blueberries'],
#  ['salmon', 'almonds'],
#  ['salmon', 'corn'],
#  ['salmon', 'butter'],
#  ['salmon', 'water spray'],
#  ['salmon', 'mashed potato'],
#  ['salmon', 'cider'],
#  ['salmon', 'burgers'],
#  ['salmon', 'whole wheat rice'],
#  ['chocolate bread', 'light mayo'],
#  ['chocolate bread', 'body spray'],
#  ['chocolate bread', 'ketchup'],
#  ['chocolate bread', 'bacon'],
#  ['chocolate bread', 'cauliflower'],
#  ['chocolate bread', 'oatmeal'],
#  ['chocolate bread', 'shallot'],
#  ['chocolate bread', 'chocolate'],
#  ['chocolate bread', 'protein bar'],
#  ['chocolate bread', 'green grapes'],
#  ['chocolate bread', 'mushroom cream sauce'],
#  ['chocolate bread', 'fromage blanc'],
#  ['chocolate bread', 'mayonnaise'],
#  ['chocolate bread', 'antioxydant juice'],
#  ['chocolate bread', 'ham'],
#  ['chocolate bread', 'black tea'],
#  ['chocolate bread', 'herb & pepper'],
#  ['chocolate bread', 'extra dark chocolate'],
#  ['chocolate bread', 'meatballs'],
#  ['chocolate bread', 'pickles'],
#  ['chocolate bread', 'french wine'],
#  ['chocolate bread', 'hot dogs'],
#  ['chocolate bread', 'hand protein bar'],
#  ['chocolate bread', 'babies food'],
#  ['chocolate bread', 'whole wheat pasta'],
#  ['chocolate bread', 'light cream'],
#  ['chocolate bread', 'muffins'],
#  ['chocolate bread', 'honey'],
#  ['chocolate bread', 'white wine'],
#  ['chocolate bread', 'green tea'],
#  ['chocolate bread', 'chutney'],
#  ['chocolate bread', 'chicken'],
#  ['chocolate bread', 'spinach'],
#  ['chocolate bread', 'olive oil'],
#  ['chocolate bread', 'strong cheese'],
#  ['chocolate bread', 'mineral water'],
#  ['chocolate bread', 'toothpaste'],
#  ['chocolate bread', 'nonfat milk'],
#  ['chocolate bread', 'tomato juice'],
#  ['chocolate bread', 'cream'],
#  ['chocolate bread', 'avocado'],
#  ['chocolate bread', 'red wine'],
#  ['chocolate bread', 'clothes accessories'],
#  ['chocolate bread', 'carrots'],
#  ['chocolate bread', 'eggs'],
#  ['chocolate bread', 'pancakes'],
#  ['chocolate bread', 'flax seed'],
#  ['chocolate bread', 'tomato sauce'],
#  ['chocolate bread', 'zucchini'],
#  ['chocolate bread', 'turkey'],
#  ['chocolate bread', 'vegetables mix'],
#  ['chocolate bread', 'escalope'],
#  ['chocolate bread', 'french fries'],
#  ['chocolate bread', 'melons'],
#  ['chocolate bread', 'whole weat flour'],
#  ['chocolate bread', 'yogurt cake'],
#  ['chocolate bread', 'candy bars'],
#  ['chocolate bread', 'bug spray'],
#  ['chocolate bread', 'soda'],
#  ['chocolate bread', 'low fat yogurt'],
#  ['chocolate bread', 'pepper'],
#  ['chocolate bread', 'gluten free bar'],
#  ['chocolate bread', ' asparagus'],
#  ['chocolate bread', 'milk'],
#  ['chocolate bread', 'tea'],
#  ['chocolate bread', 'salad'],
#  ['chocolate bread', 'frozen smoothie'],
#  ['chocolate bread', 'napkins'],
#  ['chocolate bread', 'fresh bread'],
#  ['chocolate bread', 'cake'],
#  ['chocolate bread', 'bramble'],
#  ['chocolate bread', 'grated cheese'],
#  ['chocolate bread', 'gums'],
#  ['chocolate bread', 'champagne'],
#  ['chocolate bread', 'rice'],
#  ['chocolate bread', 'chili'],
#  ['chocolate bread', 'cookies'],
#  ['chocolate bread', 'yams'],
#  ['chocolate bread', 'tomatoes'],
#  ['chocolate bread', 'pasta'],
#  ['chocolate bread', 'energy bar'],
#  ['chocolate bread', 'brownies'],
#  ['chocolate bread', 'asparagus'],
#  ['chocolate bread', 'salt'],
#  ['chocolate bread', 'green beans'],
#  ['chocolate bread', 'magazines'],
#  ['chocolate bread', 'energy drink'],
#  ['chocolate bread', 'shrimp'],
#  ['chocolate bread', 'burger sauce'],
#  ['chocolate bread', 'strawberries'],
#  ['chocolate bread', 'barbecue sauce'],
#  ['chocolate bread', 'cereals'],
#  ['chocolate bread', 'mint green tea'],
#  ['chocolate bread', 'oil'],
#  ['chocolate bread', 'mint'],
#  ['chocolate bread', 'cooking oil'],
#  ['chocolate bread', 'pet food'],
#  ['chocolate bread', 'shampoo'],
#  ['chocolate bread', 'fresh tuna'],
#  ['chocolate bread', 'sandwich'],
#  ['chocolate bread', 'soup'],
#  ['chocolate bread', 'spaghetti'],
#  ['chocolate bread', 'cottage cheese'],
#  ['chocolate bread', 'sparkling water'],
#  ['chocolate bread', 'ground beef'],
#  ['chocolate bread', 'eggplant'],
#  ['chocolate bread', 'parmesan cheese'],
#  ['chocolate bread', 'frozen vegetables'],
#  ['chocolate bread', 'dessert wine'],
#  ['chocolate bread', 'blueberries'],
#  ['chocolate bread', 'almonds'],
#  ['chocolate bread', 'corn'],
#  ['chocolate bread', 'butter'],
#  ['chocolate bread', 'water spray'],
#  ['chocolate bread', 'mashed potato'],
#  ['chocolate bread', 'cider'],
#  ['chocolate bread', 'burgers'],
#  ['chocolate bread', 'whole wheat rice'],
#  ['light mayo', 'body spray'],
#  ['light mayo', 'ketchup'],
#  ['light mayo', 'bacon'],
#  ['light mayo', 'cauliflower'],
#  ['light mayo', 'oatmeal'],
#  ['light mayo', 'shallot'],
#  ['light mayo', 'chocolate'],
#  ['light mayo', 'protein bar'],
#  ['light mayo', 'green grapes'],
#  ['light mayo', 'mushroom cream sauce'],
#  ['light mayo', 'fromage blanc'],
#  ['light mayo', 'mayonnaise'],
#  ['light mayo', 'antioxydant juice'],
#  ['light mayo', 'ham'],
#  ['light mayo', 'black tea'],
#  ['light mayo', 'herb & pepper'],
#  ['light mayo', 'extra dark chocolate'],
#  ['light mayo', 'meatballs'],
#  ['light mayo', 'pickles'],
#  ['light mayo', 'french wine'],
#  ['light mayo', 'hot dogs'],
#  ['light mayo', 'hand protein bar'],
#  ['light mayo', 'babies food'],
#  ['light mayo', 'whole wheat pasta'],
#  ['light mayo', 'light cream'],
#  ['light mayo', 'muffins'],
#  ['light mayo', 'honey'],
#  ['light mayo', 'white wine'],
#  ['light mayo', 'green tea'],
#  ['light mayo', 'chutney'],
#  ['light mayo', 'chicken'],
#  ['light mayo', 'spinach'],
#  ['light mayo', 'olive oil'],
#  ['light mayo', 'strong cheese'],
#  ['light mayo', 'mineral water'],
#  ['light mayo', 'toothpaste'],
#  ['light mayo', 'nonfat milk'],
#  ['light mayo', 'tomato juice'],
#  ['light mayo', 'cream'],
#  ['light mayo', 'avocado'],
#  ['light mayo', 'red wine'],
#  ['light mayo', 'clothes accessories'],
#  ['light mayo', 'carrots'],
#  ['light mayo', 'eggs'],
#  ['light mayo', 'pancakes'],
#  ['light mayo', 'flax seed'],
#  ['light mayo', 'tomato sauce'],
#  ['light mayo', 'zucchini'],
#  ['light mayo', 'turkey'],
#  ['light mayo', 'vegetables mix'],
#  ['light mayo', 'escalope'],
#  ['light mayo', 'french fries'],
#  ['light mayo', 'melons'],
#  ['light mayo', 'whole weat flour'],
#  ['light mayo', 'yogurt cake'],
#  ['light mayo', 'candy bars'],
#  ['light mayo', 'bug spray'],
#  ['light mayo', 'soda'],
#  ['light mayo', 'low fat yogurt'],
#  ['light mayo', 'pepper'],
#  ['light mayo', 'gluten free bar'],
#  ['light mayo', ' asparagus'],
#  ['light mayo', 'milk'],
#  ['light mayo', 'tea'],
#  ['light mayo', 'salad'],
#  ['light mayo', 'frozen smoothie'],
#  ['light mayo', 'napkins'],
#  ['light mayo', 'fresh bread'],
#  ['light mayo', 'cake'],
#  ['light mayo', 'bramble'],
#  ['light mayo', 'grated cheese'],
#  ['light mayo', 'gums'],
#  ['light mayo', 'champagne'],
#  ['light mayo', 'rice'],
#  ['light mayo', 'chili'],
#  ['light mayo', 'cookies'],
#  ['light mayo', 'yams'],
#  ['light mayo', 'tomatoes'],
#  ['light mayo', 'pasta'],
#  ['light mayo', 'energy bar'],
#  ['light mayo', 'brownies'],
#  ['light mayo', 'asparagus'],
#  ['light mayo', 'salt'],
#  ['light mayo', 'green beans'],
#  ['light mayo', 'magazines'],
#  ['light mayo', 'energy drink'],
#  ['light mayo', 'shrimp'],
#  ['light mayo', 'burger sauce'],
#  ['light mayo', 'strawberries'],
#  ['light mayo', 'barbecue sauce'],
#  ['light mayo', 'cereals'],
#  ['light mayo', 'mint green tea'],
#  ['light mayo', 'oil'],
#  ['light mayo', 'mint'],
#  ['light mayo', 'cooking oil'],
#  ['light mayo', 'pet food'],
#  ['light mayo', 'shampoo'],
#  ['light mayo', 'fresh tuna'],
#  ['light mayo', 'sandwich'],
#  ['light mayo', 'soup'],
#  ['light mayo', 'spaghetti'],
#  ['light mayo', 'cottage cheese'],
#  ['light mayo', 'sparkling water'],
#  ['light mayo', 'ground beef'],
#  ['light mayo', 'eggplant'],
#  ['light mayo', 'parmesan cheese'],
#  ['light mayo', 'frozen vegetables'],
#  ['light mayo', 'dessert wine'],
#  ['light mayo', 'blueberries'],
#  ['light mayo', 'almonds'],
#  ['light mayo', 'corn'],
#  ['light mayo', 'butter'],
#  ['light mayo', 'water spray'],
#  ['light mayo', 'mashed potato'],
#  ['light mayo', 'cider'],
#  ['light mayo', 'burgers'],
#  ['light mayo', 'whole wheat rice'],
#  ['body spray', 'ketchup'],
#  ['body spray', 'bacon'],
#  ['body spray', 'cauliflower'],
#  ['body spray', 'oatmeal'],
#  ['body spray', 'shallot'],
#  ['body spray', 'chocolate'],
#  ['body spray', 'protein bar'],
#  ['body spray', 'green grapes'],
#  ['body spray', 'mushroom cream sauce'],
#  ['body spray', 'fromage blanc'],
#  ['body spray', 'mayonnaise'],
#  ['body spray', 'antioxydant juice'],
#  ['body spray', 'ham'],
#  ['body spray', 'black tea'],
#  ['body spray', 'herb & pepper'],
#  ['body spray', 'extra dark chocolate'],
#  ['body spray', 'meatballs'],
#  ['body spray', 'pickles'],
#  ['body spray', 'french wine'],
#  ['body spray', 'hot dogs'],
#  ['body spray', 'hand protein bar'],
#  ['body spray', 'babies food'],
#  ['body spray', 'whole wheat pasta'],
#  ['body spray', 'light cream'],
#  ['body spray', 'muffins'],
#  ['body spray', 'honey'],
#  ['body spray', 'white wine'],
#  ['body spray', 'green tea'],
#  ['body spray', 'chutney'],
#  ['body spray', 'chicken'],
#  ['body spray', 'spinach'],
#  ['body spray', 'olive oil'],
#  ['body spray', 'strong cheese'],
#  ['body spray', 'mineral water'],
#  ['body spray', 'toothpaste'],
#  ['body spray', 'nonfat milk'],
#  ['body spray', 'tomato juice'],
#  ['body spray', 'cream'],
#  ['body spray', 'avocado'],
#  ['body spray', 'red wine'],
#  ['body spray', 'clothes accessories'],
#  ['body spray', 'carrots'],
#  ['body spray', 'eggs'],
#  ['body spray', 'pancakes'],
#  ['body spray', 'flax seed'],
#  ['body spray', 'tomato sauce'],
#  ['body spray', 'zucchini'],
#  ['body spray', 'turkey'],
#  ['body spray', 'vegetables mix'],
#  ['body spray', 'escalope'],
#  ['body spray', 'french fries'],
#  ['body spray', 'melons'],
#  ['body spray', 'whole weat flour'],
#  ['body spray', 'yogurt cake'],
#  ['body spray', 'candy bars'],
#  ['body spray', 'bug spray'],
#  ['body spray', 'soda'],
#  ['body spray', 'low fat yogurt'],
#  ['body spray', 'pepper'],
#  ['body spray', 'gluten free bar'],
#  ['body spray', ' asparagus'],
#  ['body spray', 'milk'],
#  ['body spray', 'tea'],
#  ['body spray', 'salad'],
#  ['body spray', 'frozen smoothie'],
#  ['body spray', 'napkins'],
#  ['body spray', 'fresh bread'],
#  ['body spray', 'cake'],
#  ['body spray', 'bramble'],
#  ['body spray', 'grated cheese'],
#  ['body spray', 'gums'],
#  ['body spray', 'champagne'],
#  ['body spray', 'rice'],
#  ['body spray', 'chili'],
#  ['body spray', 'cookies'],
#  ['body spray', 'yams'],
#  ['body spray', 'tomatoes'],
#  ['body spray', 'pasta'],
#  ['body spray', 'energy bar'],
#  ['body spray', 'brownies'],
#  ['body spray', 'asparagus'],
#  ['body spray', 'salt'],
#  ['body spray', 'green beans'],
#  ['body spray', 'magazines'],
#  ['body spray', 'energy drink'],
#  ['body spray', 'shrimp'],
#  ['body spray', 'burger sauce'],
#  ['body spray', 'strawberries'],
#  ['body spray', 'barbecue sauce'],
#  ['body spray', 'cereals'],
#  ['body spray', 'mint green tea'],
#  ['body spray', 'oil'],
#  ['body spray', 'mint'],
#  ['body spray', 'cooking oil'],
#  ['body spray', 'pet food'],
#  ['body spray', 'shampoo'],
#  ['body spray', 'fresh tuna'],
#  ['body spray', 'sandwich'],
#  ['body spray', 'soup'],
#  ['body spray', 'spaghetti'],
#  ['body spray', 'cottage cheese'],
#  ['body spray', 'sparkling water'],
#  ['body spray', 'ground beef'],
#  ['body spray', 'eggplant'],
#  ['body spray', 'parmesan cheese'],
#  ['body spray', 'frozen vegetables'],
#  ['body spray', 'dessert wine'],
#  ['body spray', 'blueberries'],
#  ['body spray', 'almonds'],
#  ['body spray', 'corn'],
#  ['body spray', 'butter'],
#  ['body spray', 'water spray'],
#  ['body spray', 'mashed potato'],
#  ['body spray', 'cider'],
#  ['body spray', 'burgers'],
#  ['body spray', 'whole wheat rice'],
#  ['ketchup', 'bacon'],
#  ['ketchup', 'cauliflower'],
#  ['ketchup', 'oatmeal'],
#  ['ketchup', 'shallot'],
#  ['ketchup', 'chocolate'],
#  ['ketchup', 'protein bar'],
#  ['ketchup', 'green grapes'],
#  ['ketchup', 'mushroom cream sauce'],
#  ['ketchup', 'fromage blanc'],
#  ['ketchup', 'mayonnaise'],
#  ['ketchup', 'antioxydant juice'],
#  ['ketchup', 'ham'],
#  ['ketchup', 'black tea'],
#  ['ketchup', 'herb & pepper'],
#  ['ketchup', 'extra dark chocolate'],
#  ['ketchup', 'meatballs'],
#  ['ketchup', 'pickles'],
#  ['ketchup', 'french wine'],
#  ['ketchup', 'hot dogs'],
#  ['ketchup', 'hand protein bar'],
#  ['ketchup', 'babies food'],
#  ['ketchup', 'whole wheat pasta'],
#  ['ketchup', 'light cream'],
#  ['ketchup', 'muffins'],
#  ['ketchup', 'honey'],
#  ['ketchup', 'white wine'],
#  ['ketchup', 'green tea'],
#  ['ketchup', 'chutney'],
#  ['ketchup', 'chicken'],
#  ['ketchup', 'spinach'],
#  ['ketchup', 'olive oil'],
#  ['ketchup', 'strong cheese'],
#  ['ketchup', 'mineral water'],
#  ['ketchup', 'toothpaste'],
#  ['ketchup', 'nonfat milk'],
#  ['ketchup', 'tomato juice'],
#  ['ketchup', 'cream'],
#  ['ketchup', 'avocado'],
#  ['ketchup', 'red wine'],
#  ['ketchup', 'clothes accessories'],
#  ['ketchup', 'carrots'],
#  ['ketchup', 'eggs'],
#  ['ketchup', 'pancakes'],
#  ['ketchup', 'flax seed'],
#  ['ketchup', 'tomato sauce'],
#  ['ketchup', 'zucchini'],
#  ['ketchup', 'turkey'],
#  ['ketchup', 'vegetables mix'],
#  ['ketchup', 'escalope'],
#  ['ketchup', 'french fries'],
#  ['ketchup', 'melons'],
#  ['ketchup', 'whole weat flour'],
#  ['ketchup', 'yogurt cake'],
#  ['ketchup', 'candy bars'],
#  ['ketchup', 'bug spray'],
#  ['ketchup', 'soda'],
#  ['ketchup', 'low fat yogurt'],
#  ['ketchup', 'pepper'],
#  ['ketchup', 'gluten free bar'],
#  ['ketchup', ' asparagus'],
#  ['ketchup', 'milk'],
#  ['ketchup', 'tea'],
#  ['ketchup', 'salad'],
#  ['ketchup', 'frozen smoothie'],
#  ['ketchup', 'napkins'],
#  ['ketchup', 'fresh bread'],
#  ['ketchup', 'cake'],
#  ['ketchup', 'bramble'],
#  ['ketchup', 'grated cheese'],
#  ['ketchup', 'gums'],
#  ['ketchup', 'champagne'],
#  ['ketchup', 'rice'],
#  ['ketchup', 'chili'],
#  ['ketchup', 'cookies'],
#  ['ketchup', 'yams'],
#  ['ketchup', 'tomatoes'],
#  ['ketchup', 'pasta'],
#  ['ketchup', 'energy bar'],
#  ['ketchup', 'brownies'],
#  ['ketchup', 'asparagus'],
#  ['ketchup', 'salt'],
#  ['ketchup', 'green beans'],
#  ['ketchup', 'magazines'],
#  ['ketchup', 'energy drink'],
#  ['ketchup', 'shrimp'],
#  ['ketchup', 'burger sauce'],
#  ['ketchup', 'strawberries'],
#  ['ketchup', 'barbecue sauce'],
#  ['ketchup', 'cereals'],
#  ['ketchup', 'mint green tea'],
#  ['ketchup', 'oil'],
#  ['ketchup', 'mint'],
#  ['ketchup', 'cooking oil'],
#  ['ketchup', 'pet food'],
#  ['ketchup', 'shampoo'],
#  ['ketchup', 'fresh tuna'],
#  ['ketchup', 'sandwich'],
#  ['ketchup', 'soup'],
#  ['ketchup', 'spaghetti'],
#  ['ketchup', 'cottage cheese'],
#  ['ketchup', 'sparkling water'],
#  ['ketchup', 'ground beef'],
#  ['ketchup', 'eggplant'],
#  ['ketchup', 'parmesan cheese'],
#  ['ketchup', 'frozen vegetables'],
#  ['ketchup', 'dessert wine'],
#  ['ketchup', 'blueberries'],
#  ['ketchup', 'almonds'],
#  ['ketchup', 'corn'],
#  ['ketchup', 'butter'],
#  ['ketchup', 'water spray'],
#  ['ketchup', 'mashed potato'],
#  ['ketchup', 'cider'],
#  ['ketchup', 'burgers'],
#  ['ketchup', 'whole wheat rice'],
#  ['bacon', 'cauliflower'],
#  ['bacon', 'oatmeal'],
#  ['bacon', 'shallot'],
#  ['bacon', 'chocolate'],
#  ['bacon', 'protein bar'],
#  ['bacon', 'green grapes'],
#  ['bacon', 'mushroom cream sauce'],
#  ['bacon', 'fromage blanc'],
#  ['bacon', 'mayonnaise'],
#  ['bacon', 'antioxydant juice'],
#  ['bacon', 'ham'],
#  ['bacon', 'black tea'],
#  ['bacon', 'herb & pepper'],
#  ['bacon', 'extra dark chocolate'],
#  ['bacon', 'meatballs'],
#  ['bacon', 'pickles'],
#  ['bacon', 'french wine'],
#  ['bacon', 'hot dogs'],
#  ['bacon', 'hand protein bar'],
#  ['bacon', 'babies food'],
#  ['bacon', 'whole wheat pasta'],
#  ['bacon', 'light cream'],
#  ['bacon', 'muffins'],
#  ['bacon', 'honey'],
#  ['bacon', 'white wine'],
#  ['bacon', 'green tea'],
#  ['bacon', 'chutney'],
#  ['bacon', 'chicken'],
#  ['bacon', 'spinach'],
#  ['bacon', 'olive oil'],
#  ['bacon', 'strong cheese'],
#  ['bacon', 'mineral water'],
#  ['bacon', 'toothpaste'],
#  ['bacon', 'nonfat milk'],
#  ['bacon', 'tomato juice'],
#  ['bacon', 'cream'],
#  ['bacon', 'avocado'],
#  ['bacon', 'red wine'],
#  ['bacon', 'clothes accessories'],
#  ['bacon', 'carrots'],
#  ['bacon', 'eggs'],
#  ['bacon', 'pancakes'],
#  ['bacon', 'flax seed'],
#  ['bacon', 'tomato sauce'],
#  ['bacon', 'zucchini'],
#  ['bacon', 'turkey'],
#  ['bacon', 'vegetables mix'],
#  ['bacon', 'escalope'],
#  ['bacon', 'french fries'],
#  ['bacon', 'melons'],
#  ['bacon', 'whole weat flour'],
#  ['bacon', 'yogurt cake'],
#  ['bacon', 'candy bars'],
#  ['bacon', 'bug spray'],
#  ['bacon', 'soda'],
#  ['bacon', 'low fat yogurt'],
#  ['bacon', 'pepper'],
#  ['bacon', 'gluten free bar'],
#  ['bacon', ' asparagus'],
#  ['bacon', 'milk'],
#  ['bacon', 'tea'],
#  ['bacon', 'salad'],
#  ['bacon', 'frozen smoothie'],
#  ['bacon', 'napkins'],
#  ['bacon', 'fresh bread'],
#  ['bacon', 'cake'],
#  ['bacon', 'bramble'],
#  ['bacon', 'grated cheese'],
#  ['bacon', 'gums'],
#  ['bacon', 'champagne'],
#  ['bacon', 'rice'],
#  ['bacon', 'chili'],
#  ['bacon', 'cookies'],
#  ['bacon', 'yams'],
#  ['bacon', 'tomatoes'],
#  ['bacon', 'pasta'],
#  ['bacon', 'energy bar'],
#  ['bacon', 'brownies'],
#  ['bacon', 'asparagus'],
#  ['bacon', 'salt'],
#  ['bacon', 'green beans'],
#  ['bacon', 'magazines'],
#  ['bacon', 'energy drink'],
#  ['bacon', 'shrimp'],
#  ['bacon', 'burger sauce'],
#  ['bacon', 'strawberries'],
#  ['bacon', 'barbecue sauce'],
#  ['bacon', 'cereals'],
#  ['bacon', 'mint green tea'],
#  ['bacon', 'oil'],
#  ['bacon', 'mint'],
#  ['bacon', 'cooking oil'],
#  ['bacon', 'pet food'],
#  ['bacon', 'shampoo'],
#  ['bacon', 'fresh tuna'],
#  ['bacon', 'sandwich'],
#  ['bacon', 'soup'],
#  ['bacon', 'spaghetti'],
#  ['bacon', 'cottage cheese'],
#  ['bacon', 'sparkling water'],
#  ['bacon', 'ground beef'],
#  ['bacon', 'eggplant'],
#  ['bacon', 'parmesan cheese'],
#  ['bacon', 'frozen vegetables'],
#  ['bacon', 'dessert wine'],
#  ['bacon', 'blueberries'],
#  ['bacon', 'almonds'],
#  ['bacon', 'corn'],
#  ['bacon', 'butter'],
#  ['bacon', 'water spray'],
#  ['bacon', 'mashed potato'],
#  ['bacon', 'cider'],
#  ['bacon', 'burgers'],
#  ['bacon', 'whole wheat rice'],
#  ['cauliflower', 'oatmeal'],
#  ['cauliflower', 'shallot'],
#  ['cauliflower', 'chocolate'],
#  ['cauliflower', 'protein bar'],
#  ['cauliflower', 'green grapes'],
#  ['cauliflower', 'mushroom cream sauce'],
#  ['cauliflower', 'fromage blanc'],
#  ['cauliflower', 'mayonnaise'],
#  ['cauliflower', 'antioxydant juice'],
#  ['cauliflower', 'ham'],
#  ['cauliflower', 'black tea'],
#  ['cauliflower', 'herb & pepper'],
#  ['cauliflower', 'extra dark chocolate'],
#  ['cauliflower', 'meatballs'],
#  ['cauliflower', 'pickles'],
#  ['cauliflower', 'french wine'],
#  ['cauliflower', 'hot dogs'],
#  ['cauliflower', 'hand protein bar'],
#  ['cauliflower', 'babies food'],
#  ['cauliflower', 'whole wheat pasta'],
#  ['cauliflower', 'light cream'],
#  ['cauliflower', 'muffins'],
#  ['cauliflower', 'honey'],
#  ['cauliflower', 'white wine'],
#  ['cauliflower', 'green tea'],
#  ['cauliflower', 'chutney'],
#  ['cauliflower', 'chicken'],
#  ['cauliflower', 'spinach'],
#  ['cauliflower', 'olive oil'],
#  ['cauliflower', 'strong cheese'],
#  ['cauliflower', 'mineral water'],
#  ['cauliflower', 'toothpaste'],
#  ['cauliflower', 'nonfat milk'],
#  ['cauliflower', 'tomato juice'],
#  ['cauliflower', 'cream'],
#  ['cauliflower', 'avocado'],
#  ['cauliflower', 'red wine'],
#  ['cauliflower', 'clothes accessories'],
#  ['cauliflower', 'carrots'],
#  ['cauliflower', 'eggs'],
#  ['cauliflower', 'pancakes'],
#  ['cauliflower', 'flax seed'],
#  ['cauliflower', 'tomato sauce'],
#  ['cauliflower', 'zucchini'],
#  ['cauliflower', 'turkey'],
#  ['cauliflower', 'vegetables mix'],
#  ['cauliflower', 'escalope'],
#  ['cauliflower', 'french fries'],
#  ['cauliflower', 'melons'],
#  ['cauliflower', 'whole weat flour'],
#  ['cauliflower', 'yogurt cake'],
#  ['cauliflower', 'candy bars'],
#  ['cauliflower', 'bug spray'],
#  ['cauliflower', 'soda'],
#  ['cauliflower', 'low fat yogurt'],
#  ['cauliflower', 'pepper'],
#  ['cauliflower', 'gluten free bar'],
#  ['cauliflower', ' asparagus'],
#  ['cauliflower', 'milk'],
#  ['cauliflower', 'tea'],
#  ['cauliflower', 'salad'],
#  ['cauliflower', 'frozen smoothie'],
#  ['cauliflower', 'napkins'],
#  ['cauliflower', 'fresh bread'],
#  ['cauliflower', 'cake'],
#  ['cauliflower', 'bramble'],
#  ['cauliflower', 'grated cheese'],
#  ['cauliflower', 'gums'],
#  ['cauliflower', 'champagne'],
#  ['cauliflower', 'rice'],
#  ['cauliflower', 'chili'],
#  ['cauliflower', 'cookies'],
#  ['cauliflower', 'yams'],
#  ['cauliflower', 'tomatoes'],
#  ['cauliflower', 'pasta'],
#  ['cauliflower', 'energy bar'],
#  ['cauliflower', 'brownies'],
#  ['cauliflower', 'asparagus'],
#  ['cauliflower', 'salt'],
#  ['cauliflower', 'green beans'],
#  ['cauliflower', 'magazines'],
#  ['cauliflower', 'energy drink'],
#  ['cauliflower', 'shrimp'],
#  ['cauliflower', 'burger sauce'],
#  ['cauliflower', 'strawberries'],
#  ['cauliflower', 'barbecue sauce'],
#  ['cauliflower', 'cereals'],
#  ['cauliflower', 'mint green tea'],
#  ['cauliflower', 'oil'],
#  ['cauliflower', 'mint'],
#  ['cauliflower', 'cooking oil'],
#  ['cauliflower', 'pet food'],
#  ['cauliflower', 'shampoo'],
#  ['cauliflower', 'fresh tuna'],
#  ['cauliflower', 'sandwich'],
#  ['cauliflower', 'soup'],
#  ['cauliflower', 'spaghetti'],
#  ['cauliflower', 'cottage cheese'],
#  ['cauliflower', 'sparkling water'],
#  ['cauliflower', 'ground beef'],
#  ['cauliflower', 'eggplant'],
#  ['cauliflower', 'parmesan cheese'],
#  ['cauliflower', 'frozen vegetables'],
#  ['cauliflower', 'dessert wine'],
#  ['cauliflower', 'blueberries'],
#  ['cauliflower', 'almonds'],
#  ['cauliflower', 'corn'],
#  ['cauliflower', 'butter'],
#  ['cauliflower', 'water spray'],
#  ['cauliflower', 'mashed potato'],
#  ['cauliflower', 'cider'],
#  ['cauliflower', 'burgers'],
#  ['cauliflower', 'whole wheat rice'],
#  ['oatmeal', 'shallot'],
#  ['oatmeal', 'chocolate'],
#  ['oatmeal', 'protein bar'],
#  ['oatmeal', 'green grapes'],
#  ['oatmeal', 'mushroom cream sauce'],
#  ['oatmeal', 'fromage blanc'],
#  ['oatmeal', 'mayonnaise'],
#  ['oatmeal', 'antioxydant juice'],
#  ['oatmeal', 'ham'],
#  ['oatmeal', 'black tea'],
#  ['oatmeal', 'herb & pepper'],
#  ['oatmeal', 'extra dark chocolate'],
#  ['oatmeal', 'meatballs'],
#  ['oatmeal', 'pickles'],
#  ['oatmeal', 'french wine'],
#  ['oatmeal', 'hot dogs'],
#  ['oatmeal', 'hand protein bar'],
#  ['oatmeal', 'babies food'],
#  ['oatmeal', 'whole wheat pasta'],
#  ['oatmeal', 'light cream'],
#  ['oatmeal', 'muffins'],
#  ['oatmeal', 'honey'],
#  ['oatmeal', 'white wine'],
#  ['oatmeal', 'green tea'],
#  ['oatmeal', 'chutney'],
#  ['oatmeal', 'chicken'],
#  ['oatmeal', 'spinach'],
#  ['oatmeal', 'olive oil'],
#  ['oatmeal', 'strong cheese'],
#  ['oatmeal', 'mineral water'],
#  ['oatmeal', 'toothpaste'],
#  ['oatmeal', 'nonfat milk'],
#  ['oatmeal', 'tomato juice'],
#  ['oatmeal', 'cream'],
#  ['oatmeal', 'avocado'],
#  ['oatmeal', 'red wine'],
#  ['oatmeal', 'clothes accessories'],
#  ['oatmeal', 'carrots'],
#  ['oatmeal', 'eggs'],
#  ['oatmeal', 'pancakes'],
#  ['oatmeal', 'flax seed'],
#  ['oatmeal', 'tomato sauce'],
#  ['oatmeal', 'zucchini'],
#  ['oatmeal', 'turkey'],
#  ['oatmeal', 'vegetables mix'],
#  ['oatmeal', 'escalope'],
#  ['oatmeal', 'french fries'],
#  ['oatmeal', 'melons'],
#  ['oatmeal', 'whole weat flour'],
#  ['oatmeal', 'yogurt cake'],
#  ['oatmeal', 'candy bars'],
#  ['oatmeal', 'bug spray'],
#  ['oatmeal', 'soda'],
#  ['oatmeal', 'low fat yogurt'],
#  ['oatmeal', 'pepper'],
#  ['oatmeal', 'gluten free bar'],
#  ['oatmeal', ' asparagus'],
#  ['oatmeal', 'milk'],
#  ['oatmeal', 'tea'],
#  ['oatmeal', 'salad'],
#  ['oatmeal', 'frozen smoothie'],
#  ['oatmeal', 'napkins'],
#  ['oatmeal', 'fresh bread'],
#  ['oatmeal', 'cake'],
#  ['oatmeal', 'bramble'],
#  ['oatmeal', 'grated cheese'],
#  ['oatmeal', 'gums'],
#  ['oatmeal', 'champagne'],
#  ['oatmeal', 'rice'],
#  ['oatmeal', 'chili'],
#  ['oatmeal', 'cookies'],
#  ['oatmeal', 'yams'],
#  ['oatmeal', 'tomatoes'],
#  ['oatmeal', 'pasta'],
#  ['oatmeal', 'energy bar'],
#  ['oatmeal', 'brownies'],
#  ['oatmeal', 'asparagus'],
#  ['oatmeal', 'salt'],
#  ['oatmeal', 'green beans'],
#  ['oatmeal', 'magazines'],
#  ['oatmeal', 'energy drink'],
#  ['oatmeal', 'shrimp'],
#  ['oatmeal', 'burger sauce'],
#  ['oatmeal', 'strawberries'],
#  ['oatmeal', 'barbecue sauce'],
#  ['oatmeal', 'cereals'],
#  ['oatmeal', 'mint green tea'],
#  ['oatmeal', 'oil'],
#  ['oatmeal', 'mint'],
#  ['oatmeal', 'cooking oil'],
#  ['oatmeal', 'pet food'],
#  ['oatmeal', 'shampoo'],
#  ['oatmeal', 'fresh tuna'],
#  ['oatmeal', 'sandwich'],
#  ['oatmeal', 'soup'],
#  ['oatmeal', 'spaghetti'],
#  ['oatmeal', 'cottage cheese'],
#  ['oatmeal', 'sparkling water'],
#  ['oatmeal', 'ground beef'],
#  ['oatmeal', 'eggplant'],
#  ['oatmeal', 'parmesan cheese'],
#  ['oatmeal', 'frozen vegetables'],
#  ['oatmeal', 'dessert wine'],
#  ['oatmeal', 'blueberries'],
#  ['oatmeal', 'almonds'],
#  ['oatmeal', 'corn'],
#  ['oatmeal', 'butter'],
#  ['oatmeal', 'water spray'],
#  ['oatmeal', 'mashed potato'],
#  ['oatmeal', 'cider'],
#  ['oatmeal', 'burgers'],
#  ['oatmeal', 'whole wheat rice'],
#  ['shallot', 'chocolate'],
#  ['shallot', 'protein bar'],
#  ['shallot', 'green grapes'],
#  ['shallot', 'mushroom cream sauce'],
#  ['shallot', 'fromage blanc'],
#  ['shallot', 'mayonnaise'],
#  ['shallot', 'antioxydant juice'],
#  ['shallot', 'ham'],
#  ['shallot', 'black tea'],
#  ['shallot', 'herb & pepper'],
#  ['shallot', 'extra dark chocolate'],
#  ['shallot', 'meatballs'],
#  ['shallot', 'pickles'],
#  ['shallot', 'french wine'],
#  ['shallot', 'hot dogs'],
#  ['shallot', 'hand protein bar'],
#  ['shallot', 'babies food'],
#  ['shallot', 'whole wheat pasta'],
#  ['shallot', 'light cream'],
#  ['shallot', 'muffins'],
#  ['shallot', 'honey'],
#  ['shallot', 'white wine'],
#  ['shallot', 'green tea'],
#  ['shallot', 'chutney'],
#  ['shallot', 'chicken'],
#  ['shallot', 'spinach'],
#  ['shallot', 'olive oil'],
#  ['shallot', 'strong cheese'],
#  ['shallot', 'mineral water'],
#  ['shallot', 'toothpaste'],
#  ['shallot', 'nonfat milk'],
#  ['shallot', 'tomato juice'],
#  ['shallot', 'cream'],
#  ['shallot', 'avocado'],
#  ['shallot', 'red wine'],
#  ['shallot', 'clothes accessories'],
#  ['shallot', 'carrots'],
#  ['shallot', 'eggs'],
#  ['shallot', 'pancakes'],
#  ['shallot', 'flax seed'],
#  ['shallot', 'tomato sauce'],
#  ['shallot', 'zucchini'],
#  ['shallot', 'turkey'],
#  ['shallot', 'vegetables mix'],
#  ['shallot', 'escalope'],
#  ['shallot', 'french fries'],
#  ['shallot', 'melons'],
#  ['shallot', 'whole weat flour'],
#  ['shallot', 'yogurt cake'],
#  ['shallot', 'candy bars'],
#  ['shallot', 'bug spray'],
#  ['shallot', 'soda'],
#  ['shallot', 'low fat yogurt'],
#  ['shallot', 'pepper'],
#  ['shallot', 'gluten free bar'],
#  ['shallot', ' asparagus'],
#  ['shallot', 'milk'],
#  ['shallot', 'tea'],
#  ['shallot', 'salad'],
#  ['shallot', 'frozen smoothie'],
#  ['shallot', 'napkins'],
#  ['shallot', 'fresh bread'],
#  ['shallot', 'cake'],
#  ['shallot', 'bramble'],
#  ['shallot', 'grated cheese'],
#  ['shallot', 'gums'],
#  ['shallot', 'champagne'],
#  ['shallot', 'rice'],
#  ['shallot', 'chili'],
#  ['shallot', 'cookies'],
#  ['shallot', 'yams'],
#  ['shallot', 'tomatoes'],
#  ['shallot', 'pasta'],
#  ['shallot', 'energy bar'],
#  ['shallot', 'brownies'],
#  ['shallot', 'asparagus'],
#  ...]

# %% [markdown]
# #### Calculating score
# The calculation is done looking at the number of customers that bought both items (the pair) and divided by all customers of the week (7501). This calculation is done for all pairs possible and the score is returned on "score" list.
#
# $ score = \frac{\text{number of lists that contain [item x and item y]}} {\text{number of all lists}} $

# %%
# %%time
score = []
for i in pair:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    score.append(len(eval(mycode))/7501.)
# Out:
# Wall time: 14 s

# %% [markdown]
# #### Showing results
#
# Top 10 Most common pairs of items of this week

# %%
ranking_ECLAT = pd.DataFrame([pair, score]).transpose()
ranking_ECLAT.columns = ['Pair', 'Score']

# %%
ranking_ECLAT.sort_values('Score', ascending=False).head(10)
# Out:
#                                     Pair     Score
# 3802          [mineral water, spaghetti]  0.059725
# 1062          [chocolate, mineral water]   0.05266
# 3745               [mineral water, eggs]  0.050927
# 3764               [mineral water, milk]  0.047994
# 3805        [mineral water, ground beef]  0.040928
# 7006            [spaghetti, ground beef]  0.039195
# 1128              [chocolate, spaghetti]  0.039195
# 4495                   [eggs, spaghetti]  0.036528
# 4446                [eggs, french fries]  0.036395
# 3808  [mineral water, frozen vegetables]  0.035729

# %% [markdown]
# ### What if we do that for trios?

# %%
# Creating trios
trio = []
for j in range(0, len(uniqueItems)):
    for k in range(j, len(uniqueItems)):
        for l in range(k, len(uniqueItems)):
            if (k != j) and (j != l) and (k != l):
                try:
                    trio.append([uniqueItems[j], uniqueItems[j+k], uniqueItems[j+l]])
                except IndexError:
                    pass

# %%
trio[:5]
# Out:
# [['salmon', 'chocolate bread', 'light mayo'],
#  ['salmon', 'chocolate bread', 'body spray'],
#  ['salmon', 'chocolate bread', 'ketchup'],
#  ['salmon', 'chocolate bread', 'bacon'],
#  ['salmon', 'chocolate bread', 'cauliflower']]

# %%
# %%time
score_trio = []
for i in trio:
    cond = []
    for item in i:
        cond.append('("%s") in s' %item)
    mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
    score_trio.append(len(eval(mycode))/7501.)
# Out:
# Wall time: 4min 13s

# %%
ranking_ECLAT_trio = pd.DataFrame([trio, score_trio]).transpose()
ranking_ECLAT_trio.columns = ['Trio', 'Score']
ranking_ECLAT_trio.sort_values('Score', ascending=False).head(10)
# Out:
#                                                  Trio     Score
# 135203        [mineral water, spaghetti, ground beef]  0.017064
# 56777           [chocolate, mineral water, spaghetti]  0.015865
# 56739                [chocolate, mineral water, milk]  0.013998
# 56720                [chocolate, mineral water, eggs]  0.013465
# 135206  [mineral water, spaghetti, frozen vegetables]  0.011998
# 56780         [chocolate, mineral water, ground beef]  0.010932
# 58667                    [chocolate, milk, spaghetti]  0.010932
# 57470                    [chocolate, eggs, spaghetti]  0.010532
# 56783   [chocolate, mineral water, frozen vegetables]  0.009732
# 56721            [chocolate, mineral water, pancakes]  0.009332

# %% [markdown]
# ## What about comparing the results from Apriori and ECLAT?

# %% [markdown]
# We got from Apriori that the combination that lead to more "attractiveness power" is "olive oil", "whole wheat pasta" and "mineral water". If we run the ECLAT code for this set of items, we will obtain: 0.0039.
#
# This score of 3 items has not enough score to be placed among top 10, but they are measuring different metrics.  According to apriori these are the items that when picked one lead to another items more frequently than other combinations, i.e. when a person pick 'olive oil', the probability of picking 'whole wheat pasta' and 'mineral water' is much higher than picking another combination. ECLAT in another hand is just sorting as the most common combinations of all lists, not caring about how one item isolatedly can influence in the purchase of another.

# %%
i = ["olive oil", "whole wheat pasta", "mineral water"]
cond = []
for item in i:
    cond.append('("{}") in s'.format(item))
mycode = ('[s for s in transactions if ' + ' and '.join(cond) + ']')
tra = eval(mycode)

# %%
cond
# Out:
# ['("olive oil") in s', '("whole wheat pasta") in s', '("mineral water") in s']

# %%
mycode
# Out:
# '[s for s in transactions if ("olive oil") in s and ("whole wheat pasta") in s and ("mineral water") in s]'

# %%
tra
# Out:
# [['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'almonds',
#   'french wine',
#   'yogurt cake',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'fresh tuna',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'olive oil',
#   'almonds',
#   'cake',
#   'chicken',
#   'extra dark chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'carrots',
#   'protein bar',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'milk',
#   'olive oil',
#   'muffins',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'chicken',
#   'salmon',
#   'pancakes',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'cooking oil',
#   'ketchup',
#   'champagne',
#   'cookies',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'chicken',
#   'gums',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'frozen smoothie',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'herb & pepper',
#   'tomatoes',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil',
#   'vegetables mix',
#   'pancakes',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'cottage cheese',
#   'energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'turkey',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'eggs',
#   'cake',
#   'cooking oil',
#   'cereals',
#   'french fries',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'olive oil',
#   'chicken',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'frozen smoothie',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'ham',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'honey',
#   'frozen smoothie',
#   'cottage cheese',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'tomatoes',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'bacon',
#   'cake',
#   'gums',
#   'pancakes',
#   'yogurt cake',
#   'tomato juice',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'french wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cake',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'energy bar',
#   'chicken',
#   'white wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'escalope',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'black tea',
#   'salmon',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'salmon',
#   'cooking oil',
#   'low fat yogurt',
#   'zucchini',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
print ('Score for "olive oil", "whole wheat pasta", "mineral water": {}'.format(len(tra)/7501.))
# Out:
# Score for "olive oil", "whole wheat pasta", "mineral water": 0.0038661511798426876
