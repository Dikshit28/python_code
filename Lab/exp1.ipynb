# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('./Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#read csv file from internet using pandas
df_internet=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/mpg_ggplot2.csv')
df_internet.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
my_array = np.array([[11,22,33],[44,55,66]])

df = pd.DataFrame(my_array, columns = ['Column_A','Column_B','Column_C'])

print(df)
print(type(df))
# Out:
#    Column_A  Column_B  Column_C
# 0        11        22        33
# 1        44        55        66
# <class 'pandas.core.frame.DataFrame'>

# %%
df_array=df.to_numpy()
print(df_array)
# Out:
# [[11 22 33]
#  [44 55 66]]

# %%
df_internet.loc[df_internet['manufacturer']=='toyota']
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 173       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 175       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 177       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 179       toyota                   camry    2.2  1999    4  manual(m5)   f
# 180       toyota                   camry    2.2  1999    4    auto(l4)   f
# 181       toyota                   camry    2.4  2008    4  manual(m5)   f
# 182       toyota                   camry    2.4  2008    4    auto(l5)   f
# 183       toyota                   camry    3.0  1999    6    auto(l4)   f
# ...

# %%
df_internet.iloc[0:5,0:]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
