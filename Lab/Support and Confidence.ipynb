# %%
#Dikshit 19csu379
# Importing the numpy and pandas libraries and giving them an alias.
import numpy as np
import pandas as pd

# %%
# Reading the csv file and storing it in a dataframe.
df = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
# Creating a new variable called `X` that is equal to the first column of `df`.
X = df.iloc[:, 0]
X
# Out:
# 0              shrimp
# 1             burgers
# 2             chutney
# 3              turkey
# 4       mineral water
#             ...
# 7496           butter
# 7497          burgers
# 7498          chicken
# 7499         escalope
# 7500             eggs
# Name: 0, Length: 7501, dtype: object

# %%
# items is a list of all the items in X.
items=[]
x = list(X)
for i in x:
    for j in i.split(","):
        items.append(j)

# %%
items
# Out:
# ['shrimp',
#  'burgers',
#  'chutney',
#  'turkey',
#  'mineral water',
#  'low fat yogurt',
#  'whole wheat pasta',
#  'soup',
#  'frozen vegetables',
#  'french fries',
#  'eggs',
#  'cookies',
#  'turkey',
#  'spaghetti',
#  'mineral water',
#  'mineral water',
#  'shrimp',
#  'turkey',
#  'turkey',
#  'meatballs',
#  'red wine',
#  'rice',
#  'spaghetti',
#  'burgers',
#  'eggs',
#  'parmesan cheese',
#  'ground beef',
#  'sparkling water',
#  'mineral water',
#  'frozen vegetables',
#  'herb & pepper',
#  'mineral water',
#  'turkey',
#  'frozen vegetables',
#  'cookies',
#  'pickles',
#  'energy bar',
#  'red wine',
#  'mineral water',
#  'pickles',
#  'spaghetti',
#  'fresh tuna',
#  'spaghetti',
#  'soup',
#  'escalope',
#  'soup',
#  'mineral water',
#  'mineral water',
#  'avocado',
#  'burgers',
#  'spaghetti',
#  'fresh tuna',
#  'spaghetti',
#  'spaghetti',
#  'french fries',
#  'tomato sauce',
#  'turkey',
#  'eggs',
#  'soup',
#  'turkey',
#  'spaghetti',
# ...

# %%
# Creating a set of unique items.
item = set(items)
item
len(item)
# Out:
# 115

# %%
#This is a loop to calculate the support of each item in item.
for j in item: 
    count=0
    for i in x: 
        if j  in i:
            count=count+1     
    support = count/len(x)
    print(j, ":",count , ";support: ", support)
# Out:
# soda : 11 ;support:  0.0014664711371817091
# escalope : 143 ;support:  0.019064124783362217
# grated cheese : 293 ;support:  0.03906145847220371
# barbecue sauce : 3 ;support:  0.0003999466737768298
# vegetables mix : 39 ;support:  0.005199306759098787
# strong cheese : 7 ;support:  0.0009332089054792694
# clothes accessories : 9 ;support:  0.0011998400213304892
# protein bar : 16 ;support:  0.0021330489268097585
# hand protein bar : 2 ;support:  0.0002666311158512198
# pepper : 293 ;support:  0.03906145847220371
# rice : 57 ;support:  0.007598986801759766
# low fat yogurt : 46 ;support:  0.0061325156645780565
# bacon : 6 ;support:  0.0007998933475536596
# cake : 209 ;support:  0.027862951606452472
# energy drink : 18 ;support:  0.0023996800426609784
# whole weat flour : 8 ;support:  0.0010665244634048793
# cooking oil : 21 ;support:  0.0027996267164378083
# flax seed : 18 ;support:  0.0023996800426609784
# butter : 52 ;support:  0.006932409012131715
# ...

# %%
# Calculating the confidence of each itemset.
for i in item:
    for j in item:
        count=0
        for k in x:
            # Checking if the itemset i and j are both in the transaction k and if they are not the same item.
            if (i in k) and (j in k) and (i != j):
                count = count+1
        conf = count/len(x)  
        print(i, "=>" ,j, "-", conf)
# Out:
# soda => soda - 0.0
# soda => escalope - 0.0
# soda => grated cheese - 0.0
# soda => barbecue sauce - 0.0
# soda => vegetables mix - 0.0
# soda => strong cheese - 0.0
# soda => clothes accessories - 0.0
# soda => protein bar - 0.0
# soda => hand protein bar - 0.0
# soda => pepper - 0.0
# soda => rice - 0.0
# soda => low fat yogurt - 0.0
# soda => bacon - 0.0
# soda => cake - 0.0
# soda => energy drink - 0.0
# soda => whole weat flour - 0.0
# soda => cooking oil - 0.0
# soda => flax seed - 0.0
# soda => butter - 0.0
# soda => frozen smoothie - 0.0
# soda => bug spray - 0.0
# soda => herb & pepper - 0.0
# soda => oil - 0.0
# soda => gluten free bar - 0.0
# soda => spaghetti - 0.0
# soda => hot dogs - 0.0
# soda => honey - 0.0
# soda => black tea - 0.0
# soda => cream - 0.0
# soda => fresh tuna - 0.0
# soda => gums - 0.0
# soda => salt - 0.0
# soda => dessert wine - 0.0
# soda => spinach - 0.0
# soda => asparagus - 0.0
# soda => magazines - 0.0
# soda => shampoo - 0.0
# ...
